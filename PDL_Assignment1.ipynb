# %% [markdown]
# # Part 1: Word Embeddings with Word Co-occurrence Matrix

# %%
# !pip install torchtext
# Out:
# Requirement already satisfied: torchtext in /Users/User2/anaconda3/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: tqdm in /Users/User2/anaconda3/lib/python3.11/site-packages (from torchtext) (4.65.0)
# Requirement already satisfied: requests in /Users/User2/anaconda3/lib/python3.11/site-packages (from torchtext) (2.31.0)
# Requirement already satisfied: torch==2.2.2 in /Users/User2/anaconda3/lib/python3.11/site-packages (from torchtext) (2.2.2)
# Requirement already satisfied: numpy in /Users/User2/anaconda3/lib/python3.11/site-packages (from torchtext) (1.24.3)
# Requirement already satisfied: filelock in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (4.12.2)
# Requirement already satisfied: sympy in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (1.11.1)
# Requirement already satisfied: networkx in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (3.1)
# Requirement already satisfied: jinja2 in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (3.1.2)
# Requirement already satisfied: fsspec in /Users/User2/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchtext) (2023.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/User2/anaconda3/lib/python3.11/site-packages (from requests->torchtext) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/User2/anaconda3/lib/python3.11/site-packages (from requests->torchtext) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/User2/anaconda3/lib/python3.11/site-packages (from requests->torchtext) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/User2/anaconda3/lib/python3.11/site-packages (from requests->torchtext) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/User2/anaconda3/lib/python3.11/site-packages (from jinja2->torch==2.2.2->torchtext) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/User2/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.2.2->torchtext) (1.3.0)

# %%
import nltk
from nltk.corpus import brown
nltk.download('brown')

corpus = ' '.join(brown.words())  # Join all words into a single text
# Out:
# [nltk_data] Downloading package brown to /Users/User2/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
def get_word_frequencies(text):
    # Convert the entire text to lowercase to normalize case
    #text = text.lower()
    
    # Split the text into words
    words = text.split()
    
    # Initialize an empty dictionary for word frequencies
    word_frequencies = {}
    
    # Count each word
    for word in words:
        if word in word_frequencies:
            word_frequencies[word] += 1
        else:
            word_frequencies[word] = 1
    
    return word_frequencies

# Example usage
word_frequencies = get_word_frequencies(corpus)

# Print word frequencies
for word, freq in word_frequencies.items():
    print(f"'{word}': {freq}")
# Out:
# 'The': 7258
# 'Fulton': 17
# 'County': 85
# 'Grand': 18
# 'Jury': 4
# 'said': 1943
# 'Friday': 60
# 'an': 3542
# 'investigation': 43
# 'of': 36080
# 'Atlanta's': 4
# 'recent': 167
# 'primary': 93
# 'election': 72
# 'produced': 90
# '``': 8837
# 'no': 1781
# 'evidence': 201
# '''': 8789
# 'that': 10237
# 'any': 1301
# 'irregularities': 8
# 'took': 425
# 'place': 528
# '.': 49346
# 'jury': 63
# 'further': 194
# 'in': 19536
# 'term-end': 1
# 'presentments': 1
# 'the': 62713
# 'City': 134
# 'Executive': 9
# 'Committee': 88
# ',': 58334
# 'which': 3540
# 'had': 5102
# 'over-all': 35
# 'charge': 120
# 'deserves': 16
# 'praise': 17
# 'and': 27915
# 'thanks': 27
# 'Atlanta': 35
# 'for': 8841
# 'manner': 124
# 'was': 9777
# 'conducted': 55
# 'September-October': 1
# 'term': 79
# 'been': 2470
# 'charged': 57
# 'by': 5103
# 'Superior': 16
# 'Court': 110
# 'Judge': 39
# 'Durwood': 1
# 'Pye': 1
# 'to': 25732
# 'investigate': 11
# 'reports': 78
# 'possible': 373
# 'hard-fought': 2
# 'won': 68
# 'Mayor-nominate': 1
# 'Ivan': 4
# 'Allen': 20
# 'Jr.': 75
# 'Only': 102
# 'a': 21881
# 'relative': 44
# 'handful': 13
# 'such': 1192
# 'received': 163
# 'considering': 39
# 'widespread': 30
# 'interest': 323
# 'number': 467
# 'voters': 18
# 'size': 138
# 'this': 3966
# 'city': 259
# 'it': 6723
# 'did': 994
# 'find': 395
# 'many': 925
# 'Georgia's': 9
# 'registration': 23
# 'laws': 87
# 'are': 4333
# 'outmoded': 4
# 'or': 4118
# 'inadequate': 32
# 'often': 349
# 'ambiguous': 22
# 'It': 2037
# 'recommended': 46
# 'legislators': 16
# 'act': 167
# 'have': 3892
# 'these': 1228
# 'studied': 79
# 'revised': 14
# 'end': 400
# 'modernizing': 4
# 'improving': 16
# 'them': 1786
# 'grand': 30
# 'commented': 18
# 'on': 6395
# 'other': 1627
# 'topics': 10
# 'among': 314
# 'purchasing': 14
# 'departments': 25
# 'well': 757
# 'operated': 27
# 'follow': 90
# 'generally': 119
# 'accepted': 94
# 'practices': 50
# 'inure': 2
# 'best': 341
# 'both': 643
# 'governments': 51
# 'Merger': 1
# 'proposed': 82
# 'However': 170
# 'believes': 43
# 'two': 1311
# 'offices': 39
# 'should': 865
# 'be': 6344
# 'combined': 39
# 'achieve': 51
# 'greater': 181
# 'efficiency': 48
# 'reduce': 62
# 'cost': 223
# 'administration': 103
# 'Purchasing': 3
# 'Department': 164
# 'is': 10011
# 'lacking': 26
# 'experienced': 53
# 'clerical': 9
# 'personnel': 72
# 'as': 6706
# 'result': 243
# 'policies': 66
# 'urged': 34
# 'take': 577
# 'steps': 115
# 'remedy': 13
# 'problem': 312
# 'Implementation': 3
# 'automobile': 43
# 'title': 52
# 'law': 277
# 'also': 999
# 'outgoing': 8
# 'next': 362
# 'Legislature': 27
# 'provide': 214
# 'enabling': 13
# 'funds': 90
# 're-set': 1
# 'effective': 128
# 'date': 102
# 'so': 1755
# 'orderly': 20
# 'implementation': 5
# 'may': 1292
# 'effected': 12
# 'swipe': 2
# 'at': 4963
# 'State': 263
# 'Welfare': 7
# 'Department's': 15
# 'handling': 37
# 'federal': 112
# 'granted': 53
# 'child': 210
# 'welfare': 46
# 'services': 128
# 'foster': 5
# 'homes': 61
# 'This': 1179
# 'one': 2873
# 'major': 227
# 'items': 71
# 'general': 311
# 'assistance': 85
# 'program': 373
# 'but': 3007
# 'has': 2425
# 'seen': 276
# 'fit': 74
# 'distribute': 6
# 'through': 941
# 'all': 2726
# 'counties': 31
# 'state': 544
# 'with': 7012
# 'exception': 40
# 'receives': 20
# 'none': 92
# 'money': 259
# 'jurors': 4
# 'they': 2773
# 'realize': 69
# 'proportionate': 9
# 'distribution': 83
# 'might': 670
# 'disable': 1
# 'our': 1142
# 'less': 426
# 'populous': 5
# 'Nevertheless': 42
# 'we': 1973
# 'feel': 216
# 'future': 215
# 'receive': 76
# 'some': 1407
# 'portion': 62
# 'available': 240
# 'Failure': 4
# 'do': 1259
# 'will': 2204
# 'continue': 105
# 'disproportionate': 2
# 'burden': 44
# 'taxpayers': 20
# 'ordinary's': 1
# 'court': 120
# 'under': 648
# 'fire': 170
# 'its': 1780
# 'appointment': 26
# 'appraisers': 1
# 'guardians': 4
# 'administrators': 5
# 'awarding': 3
# 'fees': 27
# 'compensation': 17
# 'Wards': 1
# 'protected': 31
# 'found': 536
# 'incorporated': 12
# 'into': 1782
# 'operating': 81
# 'procedures': 61
# 'recommendations': 21
# 'previous': 84
# 'juries': 1
# 'Bar': 11
# 'Association': 86
# 'interim': 10
# 'citizens': 78
# 'committee': 80
# 'These': 345
# 'actions': 67
# 'serve': 103
# 'protect': 34
# 'fact': 447
# 'effect': 213
# 'court's': 2
# 'wards': 2
# 'from': 4207
# 'undue': 13
# 'costs': 172
# 'appointed': 42
# 'elected': 32
# 'servants': 22
# 'unmeritorious': 1
# 'criticisms': 11
# 'Regarding': 1
# 'new': 1060
# 'multi-million-dollar': 2
# 'airport': 11
# 'when': 1746
# 'management': 88
# 'takes': 86
# 'Jan.': 20
# '1': 527
# 'eliminate': 25
# 'political': 254
# 'influences': 14
# 'not': 4423
# 'elaborate': 31
# 'added': 171
# 'there': 1877
# 'periodic': 8
# 'surveillance': 6
# 'pricing': 7
# 'concessionaires': 6
# 'purpose': 145
# 'keeping': 57
# 'prices': 61
# 'reasonable': 64
# 'Ask': 12
# 'jail': 17
# 'deputies': 13
# 'On': 346
# 'matters': 64
# ':': 1795
# '(': 2435
# ')': 2466
# 'Four': 34
# 'additional': 106
# 'employed': 49
# 'Jail': 4
# 'doctor': 87
# 'medical': 118
# 'intern': 2
# 'extern': 1
# 'night': 398
# 'weekend': 27
# 'duty': 58
# '2': 446
# 'work': 755
# 'officials': 56
# 'pass': 86
# 'legislation': 44
# 'permit': 75
# 'establishment': 52
# 'fair': 68
# 'equitable': 11
# 'pension': 12
# 'plan': 196
# 'employes': 15
# 'praised': 13
# 'operation': 106
# 'Police': 21
# 'Tax': 10
# 'Commissioner's': 1
# 'Office': 41
# 'Bellwood': 1
# 'Alpharetta': 1
# 'prison': 40
# 'farms': 16
# 'Grady': 5
# 'Hospital': 35
# 'Health': 17
# 'Mayor': 30
# 'William': 147
# 'B.': 76
# 'Hartsfield': 5
# 'filed': 33
# 'suit': 48
# 'divorce': 29
# 'his': 6466
# 'wife': 227
# 'Pearl': 6
# 'Williams': 32
# 'His': 530
# 'petition': 15
# 'mental': 41
# 'cruelty': 13
# 'couple': 121
# 'married': 102
# 'Aug.': 25
# '1913': 12
# 'They': 847
# 'son': 140
# 'Berry': 6
# 'daughter': 70
# 'Mrs.': 534
# 'J.': 120
# 'M.': 62
# 'Cheshire': 1
# 'Griffin': 4
# 'Attorneys': 3
# 'mayor': 8
# 'amicable': 1
# 'property': 153
# 'settlement': 25
# 'agreed': 81
# 'upon': 475
# 'listed': 42
# 'mayor's': 5
# 'occupation': 23
# 'attorney': 26
# 'age': 215
# '71': 10
# 'wife's': 15
# '74': 6
# 'birth': 63
# 'Opelika': 2
# 'Ala.': 7
# 'lived': 113
# 'together': 260
# 'man': 1151
# 'more': 2130
# 'than': 1788
# 'year': 649
# 'home': 526
# '637': 1
# 'E.': 86
# 'Pelham': 5
# 'Rd.': 3
# 'Aj': 118
# 'Henry': 83
# 'L.': 54
# 'Bowden': 2
# 'brief': 70
# 'interlude': 4
# 'since': 455
# '1937': 10
# 'career': 67
# 'goes': 89
# 'back': 950
# 'council': 27
# '1923': 7
# 'present': 370
# 'office': 214
# 'expires': 1
# 'He': 2982
# 'succeeded': 33
# 'who': 2192
# 'became': 245
# 'candidate': 34
# 'Sept.': 34
# '13': 49
# 'after': 823
# 'announced': 88
# 'he': 6566
# 'would': 2677
# 'run': 206
# 'reelection': 2
# 'Georgia': 46
# 'Republicans': 29
# 'getting': 158
# 'strong': 194
# 'encouragement': 14
# 'enter': 78
# '1962': 35
# 'governor's': 9
# 'race': 100
# 'top': 199
# 'official': 72
# 'Wednesday': 35
# 'Robert': 83
# 'Snodgrass': 2
# 'GOP': 13
# 'chairman': 48
# 'meeting': 151
# 'held': 259
# 'Tuesday': 58
# 'Blue': 46
# 'Ridge': 6
# 'brought': 253
# 'enthusiastic': 24
# 'responses': 27
# 'audience': 115
# 'Party': 21
# 'Chairman': 19
# 'James': 101
# 'W.': 83
# 'Dorsey': 1
# 'enthusiasm': 28
# 'picking': 14
# 'up': 1874
# 'rally': 10
# '8': 106
# 'Savannah': 9
# 'newly': 28
# 'Texas': 69
# 'Sen.': 30
# 'John': 360
# 'Tower': 1
# 'featured': 8
# 'speaker': 24
# 'In': 1801
# 'warned': 22
# 'entering': 24
# 'governor': 45
# 'force': 200
# 'petitions': 7
# 'out': 2058
# 'voting': 28
# 'precincts': 5
# 'obtain': 42
# 'signatures': 5
# 'registered': 22
# 'Despite': 38
# 'warning': 43
# 'unanimous': 5
# 'vote': 75
# 'according': 111
# 'attended': 36
# 'When': 585
# 'crowd': 52
# 'asked': 382
# 'whether': 258
# 'wanted': 226
# 'wait': 73
# 'make': 768
# 'voted': 27
# '--': 3432
# 'were': 3279
# 'dissents': 2
# 'largest': 53
# 'hurdle': 3
# 'face': 370
# 'says': 194
# 'before': 948
# 'making': 252
# 'first': 1242
# 'alternative': 34
# 'courses': 58
# 'must': 1003
# 'taken': 279
# 'Five': 44
# 'per': 370
# 'cent': 155
# 'each': 759
# 'county': 70
# 'sign': 91
# 'requesting': 8
# 'allowed': 86
# 'names': 88
# 'candidates': 38
# 'ballot': 12
# 'hold': 162
# 'unit': 94
# 'system': 393
# 'party': 195
# 'opposes': 2
# 'platform': 70
# 'Sam': 79
# 'Caldwell': 3
# 'Highway': 8
# 'public': 401
# 'relations': 93
# 'director': 76
# 'resigned': 9
# 'Lt.': 8
# 'Gov.': 19
# 'Garland': 8
# 'Byrd's': 3
# 'campaign': 80
# 'Caldwell's': 2
# 'resignation': 7
# 'expected': 186
# 'time': 1556
# 'Rob': 17
# 'Ledford': 1
# 'Gainesville': 1
# 'assistant': 23
# 'three': 553
# 'years': 943
# 'gubernatorial': 7
# 'starts': 30
# 'become': 359
# 'coordinator': 5
# 'Byrd': 9
# 'wind': 61
# '1961': 134
# 'session': 79
# 'Monday': 68
# 'head': 421
# 'where': 850
# 'highway': 32
# 'bond': 43
# 'approved': 37
# 'shortly': 25
# 'Before': 68
# 'adjournment': 4
# 'afternoon': 105
# 'Senate': 57
# 'approve': 14
# 'study': 239
# 'allotted': 10
# 'rural': 46
# 'urban': 41
# 'areas': 235
# 'determine': 92
# 'what': 1435
# 'adjustments': 20
# 'made': 1122
# 'Vandiver': 6
# 'traditional': 77
# 'visit': 109
# 'chambers': 8
# 'toward': 380
# 'likely': 151
# 'mention': 50
# '$100': 12
# 'million': 204
# 'issue': 144
# 'earlier': 143
# 'priority': 18
# 'item': 55
# 'Construction': 6
# 'bonds': 47
# 'Meanwhile': 22
# 'learned': 116
# 'very': 772
# 'near': 190
# 'being': 691
# 'ready': 142
# '$30': 2
# 'worth': 91
# 'reconstruction': 8
# 'go': 605
# 'courts': 45
# 'friendly': 61
# 'test': 113
# 'validity': 15
# 'then': 1025
# 'sales': 125
# 'begin': 82
# 'contracts': 24
# 'let': 293
# 'repair': 20
# 'most': 1055
# 'heavily': 59
# 'traveled': 22
# 'highways': 14
# 'A': 1314
# 'source': 90
# '$3': 3
# '$4': 5
# 'Rural': 8
# 'Roads': 4
# 'Authority': 10
# 'road': 178
# 'construction': 89
# 'revolving': 6
# 'fund': 42
# 'department': 61
# 'apparently': 104
# 'intends': 6
# 'issued': 50
# 'every': 434
# 'old': 568
# 'ones': 114
# 'paid': 144
# 'off': 634
# 'tax': 191
# 'authorities': 36
# 'opened': 131
# '1958': 91
# 'battle': 78
# 'against': 618
# 'issuance': 7
# '$50': 7
# 'roads': 54
# 'Marvin': 9
# 'told': 411
# 'Constitution': 38
# 'however': 382
# 'consulted': 17
# 'yet': 283
# 'about': 1766
# 'plans': 107
# 'Schley': 1
# 'Rep.': 13
# 'D.': 65
# 'offer': 79
# 'resolution': 62
# 'House': 191
# 'rescind': 2
# 'body's': 3
# 'action': 287
# 'itself': 304
# '$10': 7
# 'day': 623
# 'increase': 194
# 'expense': 50
# 'allowances': 25
# 'Sunday': 101
# 'research': 133
# 'done': 316
# 'quickie': 2
# 'can': 1738
# 'repealed': 3
# 'outright': 9
# 'notice': 55
# 'given': 372
# 'reconsideration': 4
# 'sought': 55
# 'While': 120
# 'emphasizing': 4
# 'technical': 115
# 'details': 57
# 'fully': 80
# 'worked': 128
# 'seek': 69
# 'set': 408
# 'aside': 57
# 'privilege': 18
# '87-31': 1
# 'similar': 146
# 'passed': 157
# '29-5': 1
# 'As': 547
# 'word': 261
# 'offered': 83
# 'pointed': 74
# 'last': 636
# 'November': 74
# 'rejected': 33
# 'constitutional': 24
# 'amendment': 17
# 'allow': 70
# 'pay': 169
# 'raises': 16
# 'sessions': 25
# 'veteran': 27
# 'Jackson': 36
# 'legislator': 7
# 'ask': 116
# 'aid': 124
# 'education': 175
# 'something': 420
# 'consistently': 19
# 'opposed': 41
# 'past': 277
# 'Mac': 1
# 'Barber': 5
# 'Commerce': 40
# 'asking': 67
# 'endorse': 6
# 'increased': 141
# 'support': 177
# 'provided': 128
# 'expended': 12
# '13th': 6
# 'members': 312
# 'congressional': 13
# 'delegation': 11
# 'Washington': 206
# 'like': 1237
# 'see': 728
# 'But': 1374
# 'congressmen': 8
# 'specifically': 36
# 'him': 2576
# 'tossed': 31
# 'hopper': 2
# 'formally': 17
# 'read': 167
# 'event': 81
# 'Congress': 150
# 'does': 445
# 'Board': 69
# 'Education': 39
# 'directed': 66
# 'give': 379
# 'teacher': 78
# 'Colquitt': 2
# 'After': 246
# 'long': 713
# 'hot': 118
# 'controversy': 26
# 'Miller': 22
# 'school': 417
# 'superintendent': 13
# 'policeman': 18
# 'put': 424
# 'coolest': 3
# 'I': 5161
# 'ever': 333
# 'saw': 350
# 'Harry': 34
# 'Davis': 27
# 'agriculture': 12
# 'defeated': 15
# 'Felix': 30
# 'Bush': 4
# 'principal': 88
# 'Democratic': 68
# '1,119': 1
# 'votes': 20
# 'Saturday's': 3
# 'got': 471
# '402': 1
# 'Ordinary': 5
# 'Carey': 5
# 'armed': 31
# 'pistol': 27
# 'stood': 212
# 'polls': 9
# 'insure': 24
# 'order': 363
# 'calmest': 1
# 'Policeman': 1
# 'Tom': 63
# 'Being': 21
# 'just': 751
# 'church': 223
# 'didn't': 393
# 'smell': 34
# 'drop': 57
# 'liquor': 42
# 'bit': 101
# 'trouble': 131
# 'leading': 65
# 'quiet': 74
# 'marked': 85
# 'anonymous': 17
# 'midnight': 23
# 'phone': 52
# 'calls': 68
# 'veiled': 6
# 'threats': 14
# 'violence': 43
# 'former': 128
# 'George': 129
# 'P.': 43
# 'Callan': 1
# 'shot': 109
# 'himself': 599
# 'death': 264
# 'March': 97
# '18': 55
# 'four': 326
# 'days': 377
# 'post': 61
# 'dispute': 34
# 'board': 170
# 'During': 132
# 'reportedly': 9
# 'telephone': 66
# 'too': 801
# 'subjected': 24
# 'soon': 176
# 'scheduled': 38
# 'Many': 105
# 'local': 273
# 'feared': 14
# 'carry': 88
# 'gun': 99
# 'promised': 45
# 'Sheriff': 5
# 'Tabb': 1
# 'ordinary': 67
# 'good': 767
# 'promise': 45
# 'Everything': 23
# 'went': 506
# 'real': 251
# 'smooth': 42
# 'sheriff': 15
# 'There': 851
# 'wasn't': 147
# 'Austin': 18
# 'approval': 51
# 'Price': 8
# 'Daniel's': 1
# 'abandoned': 25
# 'seemed': 333
# 'certain': 303
# 'Thursday': 33
# 'despite': 66
# 'adamant': 5
# 'protests': 9
# 'bankers': 11
# 'Daniel': 14
# 'personally': 35
# 'led': 130
# 'fight': 97
# 'measure': 87
# 'watered': 7
# 'down': 888
# 'considerably': 44
# 'rejection': 11
# 'Legislatures': 1
# 'hearing': 75
# 'Revenue': 16
# 'Taxation': 2
# 'Under': 59
# 'rules': 76
# 'automatically': 35
# 'subcommittee': 4
# 'week': 257
# 'questions': 133
# 'taunted': 2
# 'appearing': 16
# 'witnesses': 19
# 'left': 471
# 'little': 788
# 'doubt': 113
# 'recommend': 25
# 'passage': 48
# 'termed': 15
# 'extremely': 50
# 'conservative': 30
# 'estimate': 34
# 'produce': 82
# '17': 41
# 'dollars': 97
# 'help': 303
# 'erase': 1
# 'anticipated': 22
# 'deficit': 12
# '63': 5
# 'current': 101
# 'fiscal': 116
# '31': 38
# 'merely': 133
# 'means': 291
# 'enforcing': 5
# 'escheat': 2
# 'books': 92
# 'republic': 8
# 'permits': 27
# 'over': 1206
# 'bank': 54
# 'accounts': 36
# 'stocks': 17
# 'personal': 192
# 'persons': 117
# 'missing': 33
# 'seven': 94
# 'bill': 78
# 'drafted': 4
# 'banks': 20
# 'insurance': 41
# 'firms': 55
# 'pipeline': 4
# 'companies': 86
# 'corporations': 21
# 'report': 153
# 'treasurer': 13
# 'cannot': 258
# 'enforced': 20
# 'now': 1045
# 'because': 811
# 'almost': 406
# 'impossible': 82
# 'locate': 14
# 'declared': 66
# 'Dewey': 3
# 'Lawrence': 39
# 'Tyler': 2
# 'lawyer': 43
# 'representing': 28
# 'Bankers': 4
# 'sounded': 35
# 'opposition': 45
# 'keynote': 4
# 'violate': 7
# 'their': 2562
# 'contractual': 7
# 'obligations': 22
# 'depositors': 1
# 'undermine': 8
# 'confidence': 55
# 'customers': 39
# 'If': 732
# 'you': 2766
# 'destroy': 48
# 'economy': 76
# 'You': 520
# 'circulation': 16
# 'millions': 49
# 'Charles': 96
# 'Hughes': 27
# 'Sherman': 29
# 'sponsor': 15
# 'failure': 85
# 'enact': 7
# 'amount': 172
# 'gift': 32
# 'taxpayers'': 2
# 'pockets': 17
# 'contention': 9
# 'denied': 47
# 'several': 338
# 'including': 170
# 'Scott': 16
# 'Hudson': 53
# 'Gaynor': 1
# 'Jones': 72
# 'Houston': 25
# 'Brady': 1
# 'Harlingen': 1
# 'Howard': 32
# 'Cox': 5
# 'argued': 29
# 'probably': 236
# 'unconstitutional': 2
# 'impair': 4
# 'complained': 22
# 'enough': 426
# 'introduced': 52
# 'only': 1646
# 'Senators': 5
# 'unanimously': 10
# 'Parkhouse': 5
# 'Dallas': 58
# 'authorizing': 5
# 'schools': 190
# 'deaf': 11
# 'designed': 106
# 'special': 233
# 'schooling': 5
# 'students': 204
# 'scholastic': 9
# 'reduced': 77
# 'debate': 28
# 'authorize': 5
# 'Agency': 8
# 'establish': 58
# 'county-wide': 2
# '300,000': 6
# 'population': 136
# 'require': 85
# 'children': 342
# 'between': 716
# '6': 114
# 'attend': 54
# 'permitting': 9
# 'older': 93
# 'residential': 41
# 'School': 76
# 'Deaf': 1
# 'here': 607
# 'Operating': 6
# 'budget': 57
# 'five': 242
# 'Harris': 28
# 'Bexar': 1
# 'Tarrant': 1
# 'El': 20
# 'Paso': 10
# '$451,500': 1
# 'savings': 19
# '$157,460': 1
# 'yearly': 11
# 'year's': 36
# 'capital': 80
# 'outlay': 2
# '$88,000': 1
# 'absorbed': 24
# 'TEA': 1
# 'estimated': 65
# '182': 1
# 'scholastics': 1
# 'saving': 21
# 'coming': 170
# 'live': 175
# 'get': 719
# 'hear': 151
# 'horse': 110
# 'parimutuels': 1
# 'Reps.': 2
# 'V.': 14
# 'Red': 75
# 'Joe': 55
# 'Ratcliff': 3
# 'still': 731
# 'expects': 22
# 'tell': 245
# 'folks': 18
# 'why': 242
# 'thinks': 23
# 'Berry's': 1
# 'We're': 26
# ''': 317
# 'pro': 14
# 'letters': 110
# 'con': 7
# 'betting': 4
# 'believe': 199
# 'if': 1466
# 'people': 811
# 'better': 402
# 'informed': 56
# 'question': 250
# 'oppose': 15
# 'I'm': 269
# 'willing': 69
# 'stake': 19
# 'my': 1161
# 'ex-gambler': 1
# 'San': 70
# 'Antonio': 6
# 'advocacy': 3
# 'ponies': 6
# 'heard': 240
# 'option': 5
# 'proposal': 41
# 'favorable': 33
# 'although': 198
# 'faces': 71
# 'hard': 199
# 'sledding': 2
# 'later': 357
# 'house': 400
# 'finally': 131
# 'sent': 143
# 'extending': 28
# 'authority': 83
# 'planning': 115
# 'cities': 106
# 'senate': 5
# 'quickly': 87
# 'whipped': 12
# 'meager': 5
# 'fare': 7
# 'bills': 45
# 'committees': 15
# 'passing': 62
# 'calendar': 28
# 'One': 419
# 'validated': 1
# 'acts': 37
# 'districts': 36
# 'Another': 111
# 'enlarged': 7
# 'Beaumont': 3
# 'Navigation': 1
# 'District': 58
# 'third': 171
# 'amended': 14
# 'creation': 46
# 'Lamar': 3
# 'previously': 55
# 'adopted': 45
# 'Without': 42
# 'dissent': 5
# 'senators': 5
# 'A.': 110
# 'R.': 61
# 'Schwartz': 6
# 'Galveston': 2
# 'mentally': 15
# 'retarded': 7
# 'Gulf': 17
# 'Coast': 27
# 'district': 77
# 'Money': 6
# 'meantime': 10
# 'accept': 71
# 'gifts': 11
# 'donations': 2
# 'site': 64
# 'Two': 101
# 'revision': 8
# 'Louis': 73
# 'Crump': 1
# 'Saba': 1
# '17,000': 1
# 'retailers': 5
# 'group': 381
# 'miscellaneous': 9
# 'excise': 4
# 'taxes': 44
# 'eliminating': 14
# 'requirement': 27
# 'return': 178
# 'notarized': 1
# 'Instead': 44
# 'certificate': 7
# 'correctness': 3
# 'violation': 17
# 'penalty': 14
# 'plus': 67
# '$1,000': 11
# 'fine': 149
# 'series': 122
# 'Research': 38
# 'League': 46
# 'Aikin': 1
# 'Paris': 67
# 'relieve': 13
# 'estate': 48
# 'brokers': 4
# 'own': 772
# 'annual': 89
# 'licensing': 6
# 'fee': 16
# '$12': 1
# 'license': 36
# 'Natural': 4
# 'gas': 94
# 'utility': 29
# 'right': 597
# 'eminent': 9
# 'domain': 9
# 'Frank': 46
# 'Owen': 25
# '3': 287
# 'acquire': 27
# 'sites': 16
# 'underground': 18
# 'storage': 41
# 'reservoirs': 3
# 'Marshall': 27
# 'Formby': 1
# 'Plainview': 1
# 'Commission': 76
# 'suggested': 103
# 'fill': 49
# 'vacancies': 2
# 'need': 352
# 'costly': 16
# 'elections': 50
# 'Formby's': 1
# 'appointee': 2
# 'selected': 73
# 'composed': 40
# 'lieutenant': 12
# 'chief': 82
# 'justice': 75
# 'Supreme': 33
# 'representatives': 27
# 'decided': 141
# 'taking': 163
# 'poll': 9
# 'kind': 310
# 'Texans': 9
# 'prefer': 27
# 'An': 198
# 'adverse': 11
# '81': 3
# '65': 13
# 'kept': 186
# 'Affairs': 22
# 'referendum': 1
# 'April': 70
# '4': 206
# 'U.S.': 161
# 'senator': 3
# 'Wesley': 2
# 'Roberts': 37
# 'Seminole': 1
# 'idea': 193
# 'delay': 21
# 'kill': 62
# 'West': 187
# 'Texan': 5
# 'reported': 119
# 'gotten': 16
# 'Bill': 65
# 'Hollowell': 1
# 'Feb.': 20
# '22': 46
# 'final': 151
# 'legislative': 39
# 'two-thirds': 12
# 'majorities': 3
# 'printed': 31
# 'Opponents': 1
# 'couldn't': 173
# 'information': 258
# 'proposals': 27
# 'intelligent': 25
# 'choice': 110
# 'All': 275
# 'except': 171
# 'absent': 28
# 'Paradise': 7
# 'lost': 173
# 'alleged': 10
# 'water': 431
# 'needs': 152
# 'Texas'': 3
# 'big': 316
# 'Cotten': 4
# 'Weatherford': 2
# 'insisted': 43
# 'development': 310
# 'Representatives': 14
# 'effort': 145
# 'Fort': 47
# 'Worth': 3
# 'cover': 85
# 'places': 99
# 'Wise': 3
# 'hamlet': 3
# '250': 11
# 'shouting': 32
# 'ended': 59
# '114': 4
# 'sending': 34
# 'sponsored': 30
# 'Most': 104
# '$5,000,000': 3
# '$15,000,000': 2
# 'maximum': 78
# 'loan': 41
# 'could': 1580
# 'project': 91
# 'construed': 6
# 'large': 354
# 'felt': 357
# 'spent': 104
# 'providing': 56
# 'Statements': 1
# 'paying': 26
# 'benefit': 62
# 'pending': 13
# 'sway': 5
# 'Cotten's': 1
# 'attack': 103
# 'bill's': 2
# 'defenders': 6
# 'mostly': 38
# 'small-town': 6
# 'Buchanan': 2
# 'Dumas': 1
# 'Eligio': 1
# 'Kika': 1
# 'De': 74
# 'La': 42
# 'Garza': 1
# 'Mission': 16
# 'F.': 59
# 'Collins': 6
# 'Newton': 6
# 'Chapman': 6
# 'Sulphur': 2
# 'Springs': 13
# 'poor': 92
# 'boy's': 16
# 'peanut': 5
# 'serving': 37
# 'reducing': 30
# 'learning': 60
# 'educational': 65
# 'methods': 138
# 'C.': 93
# 'Grover': 4
# 'teaches': 11
# 'history': 268
# '24': 48
# '12': 96
# 'semester': 10
# 'hours': 173
# 'so-called': 31
# 'teaching': 61
# 'required': 181
# 'junior': 29
# 'senior': 31
# 'high': 461
# 'normal': 135
# 'college': 163
# '30': 112
# 'junior-senior': 1
# 'teachers': 64
# 'least': 343
# 'credit': 55
# 'subject': 158
# 'remainder': 19
# '4-year': 2
# 'subjects': 80
# 'person': 170
# 'master's': 6
# 'degree': 125
# 'physics': 19
# 'chemistry': 16
# 'math': 3
# 'English': 195
# 'permitted': 57
# 'teach': 41
# 'College': 104
# 'Fifty-three': 1
# '150': 9
# 'immediately': 117
# 'joined': 55
# 'co-signers': 1
# 'sp.': 2
# 'regents': 2
# 'Junior': 46
# 'named': 82
# 'Dr.': 192
# 'Clarence': 8
# 'Clark': 35
# 'Hays': 6
# 'Kan.': 3
# 'school's': 3
# 'president': 125
# 'succeed': 14
# 'McLemore': 1
# 'retire': 9
# 'close': 230
# 'holds': 41
# 'earned': 18
# 'Doctor': 13
# 'University': 124
# 'Oklahoma': 13
# 'Master': 11
# 'Science': 26
# '&': 163
# 'Bachelor': 2
# 'Southwestern': 2
# 'Okla.': 3
# 'addition': 141
# 'Rhode': 105
# 'Island': 135
# 'Massachusetts': 50
# 'Institute': 45
# 'Technology': 8
# 'captain': 44
# 'basketball': 8
# 'team': 81
# 'football': 30
# 'letterman': 1
# 'served': 119
# 'athletic': 13
# 'Raymondville': 1
# 'High': 36
# 'instructor': 8
# 'associate': 17
# 'professor': 27
# 'border': 14
# 'patrolman': 6
# 'Signal': 7
# 'Corps': 84
# 'Army': 74
# 'Denton': 4
# 'Principals': 1
# 'Independent': 4
# 're-elected': 3
# '1961-62': 2
# 'recommendation': 24
# 'Supt.': 2
# 'Chester': 10
# 'O.': 29
# 'Strickland': 1
# 'racial': 24
# 'discrimination': 23
# 'employment': 44
# 'called': 396
# 'yesterday': 80
# 'blue': 97
# 'ribbon': 12
# 'dependent': 39
# 'culminating': 2
# 'ADC': 8
# 'Cook': 23
# 'New': 575
# 'York': 302
# 'consulting': 10
# 'firm': 108
# '10': 152
# 'range': 154
# 'soaring': 4
# 'case': 355
# 'load': 45
# 'serious': 113
# 'causes': 57
# 'family': 311
# 'breakdown': 13
# 'desertion': 2
# 'dependency': 3
# 'Must': 10
# 'solve': 20
# 'monthly': 20
# '100,000': 9
# 'recipients': 5
# '4.4': 1
# 'Virgil': 2
# 'Martin': 55
# 'Carson': 2
# 'Pirie': 1
# 'Co.': 48
# 'We': 679
# 'problems': 240
# 'forced': 79
# 'depend': 45
# 'subsistence': 10
# 'volume': 115
# 'cases': 147
# 'decrease': 15
# 'community': 214
# 'able': 216
# 'deal': 134
# 'effectively': 36
# 'Relatively': 1
# 'limited': 102
# 'skills': 37
# 'color': 137
# 'underlying': 17
# 'breakups': 1
# 'Calls': 2
# 'extension': 34
# 'Other': 75
# 'Extension': 2
# 'living': 185
# 'relatives': 21
# 'parents': 81
# 'preserving': 7
# 'unity': 66
# 'projects': 65
# 'prevention': 25
# 'illegitimacy': 4
# 'Several': 39
# 'defendants': 10
# 'Summerdale': 2
# 'police': 134
# 'burglary': 4
# 'trial': 118
# 'statements': 67
# 'indicating': 15
# 'guilt': 33
# 'arrest': 19
# 'Parsons': 5
# 'Criminal': 4
# 'disclosure': 2
# 'Bellows': 6
# 'defense': 126
# 'counsel': 14
# 'startled': 19
# 'observers': 18
# 'viewed': 24
# 'prelude': 3
# 'quarrel': 20
# 'six': 196
# 'attorneys': 6
# 'eight': 93
# 'policemen': 14
# 'grant': 35
# 'client': 15
# 'Alan': 5
# 'Clements': 3
# 'separate': 76
# 'request': 49
# 'while': 560
# 'all-woman': 1
# 'courtroom': 2
# 'Fears': 1
# 'prejudicial': 4
# 'aspects': 63
# 'highly': 93
# 'Some': 211
# 'strongly': 37
# 'indicated': 108
# 'knew': 395
# 'receiving': 32
# 'stolen': 18
# 'involving': 33
# 'themselves': 270
# 'others': 294
# 'leaned': 38
# 'bench': 28
# 'inquired': 16
# 'mean': 199
# 'admitting': 7
# '?': 4693
# 'Yes': 89
# 'your': 868
# 'honor': 62
# 'replied': 55
# 'What': 473
# 'amounts': 44
# 'true': 217
# 'free-for-all': 1
# 'conflict': 51
# 'July': 66
# 'President': 257
# 'Kennedy': 140
# 'today': 246
# 'pushed': 53
# 'White': 111
# 'business': 363
# 'devote': 15
# 'attention': 177
# 'working': 148
# 'Berlin': 74
# 'crisis': 77
# 'address': 76
# 'deliver': 18
# 'tomorrow': 59
# 'American': 569
# 'nationwide': 5
# 'television': 49
# 'radio': 105
# 'much': 900
# 'week-end': 5
# 'summer': 132
# 'Cape': 17
# 'Cod': 5
# 'writing': 111
# 'drafts': 3
# 'portions': 11
# 'aids': 22
# 'whom': 143
# 'talked': 58
# 'Shortly': 9
# 'Chief': 37
# 'returned': 115
# 'midmorning': 1
# 'Hyannis': 2
# 'Port': 8
# 'Mass.': 12
# 'spokesman': 13
# 'text': 54
# 'quite': 271
# 'way': 892
# 'completion': 36
# 'Decisions': 2
# 'Asked': 16
# 'Pierre': 17
# 'Salinger': 4
# 'press': 104
# 'secretary': 39
# 'say': 495
# 'it's': 142
# 'thru': 15
# 'advisers': 12
# 'staff': 103
# 'doing': 163
# 'involved': 147
# 'composition': 25
# 'wording': 4
# 'rather': 354
# 'minute': 54
# 'decisions': 52
# 'meet': 147
# 'latest': 34
# 'precipitated': 9
# 'Russia's': 14
# 'demands': 55
# 'Nov.': 21
# 'dismissed': 14
# 'Acting': 9
# 'Karns': 7
# 'prosecution': 9
# 'obtained': 115
# 'unfair': 13
# 'fundamentally': 8
# 'illegal': 9
# 'matter': 306
# 'even': 985
# 'significance': 66
# 'innocence': 28
# '50': 61
# 'legal': 71
# 'rights': 69
# 'Karns'': 1
# 'ruling': 19
# 'pertained': 1
# 'ruled': 31
# 'unable': 54
# 'Contempt': 1
# 'proceedings': 18
# 'originally': 21
# '677': 2
# '133': 4
# 'Morris': 21
# 'Wexler': 6
# 'prosecutor': 2
# 'Issue': 8
# 'subpoenas': 1
# 'admitted': 44
# 'hearings': 8
# 'subpenas': 1
# '200': 38
# 'questioned': 28
# 'individuals': 72
# 'building': 147
# 'Mayer': 5
# 'Goldberg': 10
# 'judges': 18
# '58th': 2
# 'precinct': 6
# '23d': 5
# 'ward': 22
# 'procedure': 76
# 'constituted': 11
# 'intimidation': 5
# 'repeatedly': 18
# 'coercion': 4
# 'used': 610
# 'questioning': 21
# 'wrongful': 1
# 'privately': 10
# 'outside': 190
# 'room': 366
# 'misuse': 5
# 'processes': 57
# 'Actually': 38
# 'abuse': 16
# 'process': 195
# 'contempt': 14
# 'altho': 2
# 'vindication': 3
# 'function': 113
# 'judge': 38
# 'East': 141
# 'St.': 164
# 'sitting': 92
# 'Faced': 4
# '35': 18
# 'complementary': 4
# 'miscount': 1
# 'another': 573
# '33d': 1
# '24th': 7
# '42d': 1
# '31st': 2
# '21st': 3
# '28th': 6
# '29th': 5
# '18th': 9
# '4th': 8
# '9th': 7
# 'advisement': 2
# 'Claims': 9
# 'precedent': 9
# 'reading': 138
# 'statement': 141
# 'discharging': 3
# 'subpenaed': 1
# 'dismiss': 5
# '9': 62
# 'mammoth': 4
# 'care': 160
# 'whereby': 19
# 'social': 356
# 'security': 74
# '70': 24
# 'workers': 80
# 'raised': 101
# 'hospital': 75
# '14.2': 1
# 'Americans': 93
# 'covered': 104
# 'railroad': 47
# 'retirement': 24
# 'programs': 138
# 'message': 63
# 'tied': 34
# 'aged': 18
# 'requests': 11
# 'grants': 20
# 'finance': 27
# 'dental': 12
# 'scholarships': 8
# 'build': 85
# '20': 92
# 'expand': 13
# 'health': 88
# 'Capitol': 21
# 'hill': 38
# 'Cost': 6
# '$37': 3
# 'financed': 16
# 'boosting': 3
# 'payroll': 16
# 'worker': 30
# 'employer': 14
# '$4,800': 1
# 'alone': 191
# 'boost': 15
# 'base': 84
# '$5,000': 6
# '6.5': 1
# '3.25': 1
# 'Similar': 11
# 'boosts': 1
# 'imposed': 19
# 'those': 782
# 'actually': 128
# 'rise': 101
# '7.5': 4
# 'starting': 61
# '1963': 8
# 'levy': 7
# 'already': 257
# 'Outlays': 1
# 'Officials': 6
# '1.5': 12
# 'billion': 62
# 'benefits': 33
# 'Both': 87
# 'figures': 100
# 'higher': 151
# 'parts': 109
# 'entail': 5
# '750': 4
# 'Nursing': 3
# 'carries': 22
# 'systems': 125
# 'Full': 5
# 'payment': 52
# 'stays': 5
# '90': 11
# 'illness': 20
# 'patient': 86
# 'nine': 74
# 'nursing': 14
# '180': 8
# 'following': 205
# 'discharge': 19
# '300': 25
# 'paid-for': 1
# 'formula': 58
# 'allowing': 31
# 'use': 566
# 'part': 465
# 'hospital-care': 1
# 'outpatient': 1
# 'clinic': 3
# 'diagnostic': 10
# 'service': 245
# 'excess': 42
# '$20': 6
# 'Community': 17
# 'visiting': 35
# 'nurse': 16
# '240': 2
# 'noted': 89
# 'states': 158
# 'needy': 5
# 'modest': 29
# 'wish': 109
# 'nevertheless': 31
# 'staggered': 12
# 'drain': 15
# 'caused': 90
# 'extended': 55
# 'stay': 107
# 'cut': 180
# 'absolutely': 27
# 'essential': 81
# 'sufficient': 62
# 'deductible': 4
# 'requirements': 82
# 'discourage': 9
# 'malingering': 2
# 'unnecessary': 16
# 'overcrowding': 1
# 'hospitals': 18
# 'socialized': 3
# 'medicine': 25
# 'prepayment': 1
# 'absolute': 30
# 'freedom': 119
# 'guaranteed': 13
# 'Every': 57
# 'choose': 48
# 'Wouldn't': 4
# 'doctors': 27
# 'Apart': 10
# 'President's': 23
# 'ambitious': 16
# 'enlarge': 7
# 'nation's': 32
# '92': 3
# '47': 9
# 'handle': 51
# 'student': 109
# 'needed': 187
# 'rising': 60
# 'Moreover': 67
# 'qualified': 24
# 'young': 359
# 'going': 392
# 'dentistry': 1
# 'can't': 151
# 'afford': 40
# 'Contributions': 1
# 'scholarship': 34
# 'contributions': 28
# 'equal': 88
# '$1,500': 4
# 'one-fourth': 6
# 'based': 116
# '$2,000': 6
# 'government': 272
# '5.1': 1
# '21': 47
# '1966': 4
# 'matching': 30
# 'totaling': 5
# '700': 6
# 'constructing': 7
# 'enlarging': 3
# 'capacity': 83
# 'existing': 60
# 'More': 85
# 'area': 319
# 'doubling': 7
# 'dollar': 43
# 'initial': 66
# 'appropriation': 4
# 'stimulatory': 1
# 'improve': 37
# 'unspecified': 4
# 'sum': 44
# 'experimental': 33
# 'field': 243
# 'children's': 21
# 'bureau': 17
# 'national': 212
# 'institute': 5
# 'Asks': 1
# 'vocational': 69
# 'rehabilitation': 20
# 'how': 623
# 'For': 648
# 'facilities': 98
# 'propose': 13
# 'increasing': 71
# '540': 2
# 'direct': 122
# 'combine': 14
# 'indispensable': 15
# 'elements': 103
# 'sound': 201
# 'knowledge': 143
# 'Reaction': 3
# 'Congressional': 9
# 'reaction': 121
# 'along': 342
# 'lines': 194
# 'Legislators': 4
# 'placing': 26
# 'aged-care': 1
# 'criticized': 14
# 'Those': 68
# 'backed': 24
# 'hailed': 7
# 'Republican': 54
# 'Leader': 5
# 'Dirksen': 3
# 'Ill.': 13
# 'Halleck': 3
# 'Ind.': 2
# 'persuade': 17
# 'change': 237
# 'compulsory': 6
# 'voluntary': 22
# 'enacted': 12
# 'Speaker': 25
# 'Rayburn': 39
# 'Tex.': 7
# 'mighty': 27
# 'thing': 331
# 'prediction': 10
# 'fate': 29
# 'hastily': 14
# 'pressure': 184
# 'tonight': 34
# 'confirmed': 20
# 'Weaver': 4
# 'housing': 50
# '11': 62
# 'floor': 157
# 'record': 134
# 'scattered': 27
# 'ayes': 1
# 'noes': 1
# 'Customary': 1
# 'ignored': 29
# 'speed': 80
# 'Negro': 107
# 'leader': 69
# 'administrator': 14
# 'agency': 48
# 'Presidential': 23
# 'appointments': 6
# 'cabinet': 12
# 'rank': 22
# 'immediate': 81
# 'rule': 68
# 'requiring': 16
# 'hour': 145
# 'Enforce': 1
# 'demand': 101
# 'Wayne': 12
# 'Morse': 29
# 'Ore.': 3
# 'connection': 68
# 'Eisenhower's': 11
# 'selections': 14
# '1953': 26
# 'Kennedy's': 26
# 'Oslo': 5
# 'positive': 72
# 'element': 52
# 'emerge': 18
# 'North': 144
# 'Atlantic': 40
# 'Treaty': 7
# 'Organization': 18
# 'Foreign': 23
# 'Ministers': 3
# 'freer': 5
# 'franker': 1
# 'wider': 15
# 'discussions': 31
# 'animated': 5
# 'mutual': 21
# 'understanding': 119
# 'meetings': 28
# 'organization': 110
# 'nature': 186
# 'proceed': 18
# 'route': 33
# 'step': 130
# 'without': 541
# 'dramatic': 62
# 'changes': 126
# 'ministers': 9
# 'met': 129
# 'climate': 26
# 'candor': 2
# 'genuine': 34
# 'attempt': 95
# 'another's': 5
# 'atmosphere': 79
# 'particularly': 142
# 'noticeable': 11
# 'concerned': 135
# 'colonialist': 1
# 'powers': 67
# 'never': 664
# 'nightmare': 9
# 'clash': 5
# 'Africa': 45
# 'exacerbated': 2
# 'difficulties': 46
# 'tragedies': 7
# 'facing': 31
# 'allies': 24
# 'intellectually': 5
# 'emotionally': 11
# 'disapprove': 4
# 'circumstances': 82
# 'troubles': 22
# 'conspicuous': 6
# 'absence': 53
# 'Explosion': 1
# 'avoided': 19
# 'Portugal': 4
# 'few': 583
# 'weeks': 139
# 'ago': 246
# 'rumored': 2
# 'walk': 96
# 'NATO': 25
# 'Council': 76
# 'critics': 26
# 'Angola': 3
# 'policy': 221
# 'prove': 53
# 'harsh': 12
# 'relaxation': 7
# 'tension': 56
# 'remarkably': 18
# 'courteous': 6
# 'explanation': 43
# 'basic': 163
# 'positions': 54
# 'unchanged': 9
# 'explosion': 15
# 'bitter': 52
# 'surprises': 5
# 'UN': 11
# 'General': 187
# 'Assembly': 29
# 'members'': 2
# 'ad': 10
# 'hoc': 3
# 'discussed': 64
# 'advance': 56
# 'Canada': 34
# 'somewhat': 123
# 'allied': 10
# 'cars': 109
# 'track': 37
# 'behind': 244
# 'locomotive': 2
# 'Even': 185
# 'Norway': 2
# 'daily': 99
# 'manifestations': 9
# 'atomic': 38
# 'arms': 115
# 'heart': 170
# 'northernmost': 1
# 'alliance': 14
# 'closer': 60
# 'line': 282
# 'negative': 53
# 'side': 370
# 'balance': 90
# 'sheet': 45
# 'disappointment': 15
# 'United': 463
# 'States': 445
# 'leadership': 89
# 'hoped': 48
# 'diplomat': 5
# 'described': 120
# 'tenor': 6
# 'Secretary': 152
# 'Dean': 27
# 'Rusk's': 3
# 'speeches': 20
# 'inconclusive': 3
# 'hastened': 9
# 'add': 79
# 'always': 449
# 'clear': 219
# 'Mr.': 844
# 'analysis': 103
# 'various': 195
# 'global': 4
# 'danger': 68
# 'points': 143
# 'setbacks': 3
# 'firmly': 49
# 'fixed': 81
# 'Exploratory': 1
# 'mood': 36
# 'vagueness': 3
# 'tactical': 8
# 'appreciation': 22
# 'semipublic': 1
# 'affair': 33
# 'fewer': 33
# 'Soviet': 128
# 'correspondents': 5
# 'accredited': 2
# 'impression': 45
# 'during': 453
# 'popularity': 17
# 'came': 621
# 'tentative': 15
# 'exploratory': 3
# 'frame': 73
# 'mind': 324
# 'listen': 34
# 'learn': 83
# 'enunciate': 1
# 'scale': 55
# 'detailed': 50
# 'application': 64
# 'individual': 233
# 'spots': 31
# 'speech': 61
# 'gave': 285
# 'tremendous': 37
# 'march': 24
# 'events': 99
# 'inside': 162
# 'preoccupied': 10
# 'months': 188
# 'core': 42
# 'reiterated': 2
# 'States'': 4
# 'profound': 27
# 'attachment': 5
# 'cornerstone': 3
# 'foreign': 135
# 'nuclear': 110
# 'submarines': 19
# 'eventually': 43
# 'NATO's': 1
# 'disposal': 20
# 'European': 61
# 'waters': 36
# 'solemnly': 8
# 'repeated': 56
# 'Union': 104
# 'stand': 145
# 'setback': 3
# 'affirmation': 4
# 'once': 414
# 'again': 534
# 'whole': 306
# 'Conflict': 1
# 'surveyed': 9
# 'secretary's': 4
# 'greatest': 84
# 'achievement': 57
# 'perhaps': 214
# 'rekindling': 1
# 'realization': 24
# 'East-West': 4
# 'friction': 17
# 'wherever': 24
# 'around': 556
# 'globe': 12
# 'essence': 15
# 'entirely': 90
# 'different': 306
# 'societies': 40
# 'treated': 75
# 'regard': 89
# 'geographical': 16
# 'distance': 108
# 'lack': 109
# 'apparent': 57
# 'spring': 107
# 'impetus': 6
# 'main': 108
# 'directions': 25
# 'deeper': 37
# 'timely': 9
# 'consultation': 8
# 'within': 321
# 'Economic': 24
# 'Cooperation': 3
# 'Development': 24
# 'ratified': 3
# 'method': 137
# 'coordinating': 4
# 'underdeveloped': 10
# 'countries': 148
# 'strengthening': 12
# 'conventional': 49
# 'forces': 148
# 'maintenance': 59
# 'deterrent': 7
# 'threshold': 14
# 'alliance's': 1
# 'difficult': 160
# 'come': 589
# 'Each': 118
# 'ally': 9
# 'laid': 77
# 'completely': 110
# 'fulfilled': 11
# 'moves': 36
# 'haltingly': 2
# 'Geneva': 17
# 'conference': 61
# 'Laos': 64
# 'erupts': 1
# 'optimism': 15
# 'Communists': 39
# 'docile': 4
# 'table': 147
# 'military': 196
# 'ground': 184
# 'explain': 63
# 'mainly': 29
# 'interested': 104
# 'setting': 59
# 'international': 117
# 'inspection': 20
# 'prevent': 83
# 'Communist': 92
# 'attacks': 20
# 'neighboring': 24
# 'Thailand': 4
# 'South': 181
# 'Viet': 16
# 'Nam': 13
# 'count': 43
# 'neutral': 33
# 'attending': 22
# 'hopes': 49
# 'Lao': 17
# 'Cabinet': 5
# 'dominated': 19
# 'acceptable': 20
# 'possibility': 87
# 'Policies': 2
# 'modified': 13
# 'inclination': 8
# 'de': 48
# 'facto': 7
# 'cease-fire': 7
# 'insist': 27
# 'verification': 4
# 'control': 209
# 'commission': 27
# 'participating': 14
# 'modifications': 5
# 'compelled': 18
# 'excuses': 2
# 'chain': 48
# 'errors': 41
# 'Its': 78
# 'spokesmen': 12
# 'reforms': 14
# 'economic': 219
# 'critical': 55
# 'moving': 110
# 'confrontations': 1
# 'showing': 61
# 'gain': 73
# 'free': 243
# 'world': 684
# 'arises': 14
# 'How': 211
# 'dealing': 41
# 'aggression': 10
# 'Former': 3
# 'Vice-President': 3
# 'Richard': 71
# 'Nixon': 25
# 'Detroit': 21
# 'firmer': 6
# 'tougher': 9
# 'feels': 45
# 'tendency': 49
# 'conciliatory': 2
# 'restrained': 13
# 'Gallup': 1
# 'understates': 1
# 'situation': 196
# 'hardly': 99
# 'restrain': 10
# 'raising': 34
# 'power': 326
# 'amateurish': 3
# 'monumental': 5
# 'blunders': 1
# 'Cuba': 47
# 'correspondent': 12
# 'constantly': 41
# 'score': 59
# 'reply': 37
# 'country': 312
# 'politics': 65
# 'wisdom': 42
# 'Senator': 37
# 'Thruston': 1
# 'Morton': 15
# 'R': 37
# 'Kentucky': 14
# 'National': 163
# 'responsible': 71
# 'outcome': 26
# 'coalition': 15
# 'susceptible': 6
# 'domination': 15
# 'assailed': 4
# 'direction': 132
# 'Harvard': 34
# 'Boston': 61
# 'Brandeis': 1
# 'educators': 6
# 'Detente': 1
# 'pleads': 1
# 'invasion': 15
# 'exile': 4
# 'groups': 125
# 'recommends': 2
# 'instead': 129
# 'detach': 1
# 'Castro': 32
# 'regime': 23
# 'bloc': 10
# 'diplomatic': 27
# 'detente': 1
# 'resumption': 9
# 'trade': 134
# ';': 5566
# 'concentrate': 11
# 'constructive': 15
# 'efforts': 125
# 'Latin': 50
# 'America': 194
# 'conditions': 179
# 'totalitarian': 6
# 'nationalism': 34
# 'feeds': 10
# 'intervention': 20
# 'specific': 109
# 'provocation': 5
# 'clearly': 118
# 'shipped': 6
# 'tolerated': 6
# 'Until': 28
# 'Cuban': 19
# 'fiasco': 4
# 'victories': 7
# 'observer': 13
# 'blended': 4
# 'respected': 11
# 'opinions': 44
# 'voiced': 5
# 'professors': 14
# 'Aid': 6
# 'revamped': 3
# 'Very': 24
# 'early': 333
# 'Kremlin': 11
# 'channels': 23
# 'disclosed': 14
# 'react': 15
# 'Eisenhower': 50
# 'formative': 2
# 'period': 263
# 'Strenuous': 1
# 'remove': 50
# 'pin': 15
# 'pricking': 1
# 'ban': 7
# 'negotiations': 20
# 'reviewed': 13
# 'changed': 95
# 'thus': 146
# 'far': 409
# 'response': 76
# 'emphasis': 58
# 'encourage': 45
# 'reform': 26
# 'recipient': 7
# 'nations': 117
# 'looked': 366
# 'show': 271
# 'determination': 39
# 'sailing': 19
# 'naval': 20
# 'fleet': 12
# 'Southeast': 18
# 'Asian': 10
# 'useless': 17
# 'gesture': 32
# 'Again': 43
# 'freeze': 6
# 'aided': 11
# 'Pathet': 10
# 'faster': 18
# 'rate': 209
# 'And': 938
# 'territory': 27
# 'exposed': 34
# 'huge': 53
# 'build-up': 4
# 'acclaimed': 4
# 'performing': 17
# 'great': 608
# 'Asia': 44
# 'SEATO': 5
# 'steamed': 6
# 'prepared': 102
# 'contingency': 3
# 'coping': 7
# 'losses': 46
# 'want': 326
# 'risk': 53
# 'all-out': 6
# 'war': 305
# 'disagreed': 3
# 'complication': 4
# 'concluded': 32
# 'ill': 26
# 'suited': 22
# 'unlike': 33
# 'determined': 119
# 'neighbors': 40
# 'favor': 77
# 'neutralized': 5
# 'pro-Western': 12
# 'helped': 66
# 'revolt': 8
# 'Souvanna': 6
# 'Phouma': 4
# 'neutralist': 8
# 'appear': 117
# 'spark': 10
# 'fighting': 63
# 'spirit': 160
# 'Royal': 22
# 'certainly': 117
# 'energy': 96
# 'displayed': 20
# 'hilt': 3
# 'ideas': 138
# 'Prince': 31
# 'trusting': 4
# 'gradually': 43
# 'relinquish': 6
# 'factor': 71
# 'Fulbright': 2
# 'D': 50
# 'Arkansas': 18
# 'Relations': 9
# '25': 82
# 'erred': 3
# 'half': 263
# 'encouraging': 20
# 'removal': 40
# 'extraordinary': 30
# 'check': 74
# 'rapid': 43
# 'growth': 151
# 'juvenile': 15
# 'delinquency': 4
# 'deeply': 39
# 'vitality': 17
# 'nation': 118
# 'important': 365
# 'assertion': 7
# 'executive': 46
# 'establishing': 26
# 'Juvenile': 3
# 'Delinquency': 3
# 'Crime': 3
# 'supported': 54
# 'assisted': 7
# 'Citizens': 8
# 'Advisory': 14
# 'recognized': 80
# 'asks': 17
# 'cooperation': 36
# 'enactment': 7
# 'specified': 28
# 'combating': 1
# 'disturbing': 16
# 'crime': 32
# 'trend': 46
# 'Offenses': 1
# 'multiply': 4
# 'Attorney': 39
# 'Labor': 30
# 'coordinate': 10
# 'assist': 25
# 'communities': 41
# 'cope': 21
# 'Simultaneously': 6
# 'David': 51
# 'Hackett': 1
# 'Youth': 9
# 'sense': 311
# 'urgency': 12
# 'stems': 32
# 'arrests': 3
# 'doubled': 11
# '1948': 21
# 'offenders': 2
# 'Among': 56
# 'Federal': 134
# 'Bureau': 26
# 'Investigation': 8
# '1959': 102
# 'larceny': 2
# 'Providence': 77
# 'organize': 14
# 'civil': 45
# 'setup': 8
# 'appointing': 1
# 'full-time': 24
# 'Raymond': 17
# 'H.': 71
# 'Hawksley': 10
# 'CD': 8
# 'anyone': 128
# 'else': 176
# 'locally': 11
# 'outline': 11
# 'earliest': 22
# 'state's': 19
# 'part-time': 23
# 'Noting': 5
# 'handed': 38
# 'Defense': 41
# 'responsibility': 116
# 'salary': 41
# 'expressed': 74
# 'opinion': 94
# 'hire': 15
# '$3,500': 1
# 'basis': 184
# 'defray': 2
# 'believed': 77
# 'residents': 20
# 'job': 236
# 'men': 736
# 'Fire': 17
# 'Laughlin': 2
# 'Along': 13
# 'headquarters': 56
# 'pertinent': 21
# 'centralized': 9
# 'advantage': 73
# 'having': 258
# 'eligible': 14
# 'apply': 56
# 'financial': 81
# 'equipment': 164
# 'Matching': 3
# 'procurement': 20
# 'radios': 7
# 'sirens': 2
# 'rescue': 14
# 'trucks': 22
# 'vehicle': 33
# 'Central': 59
# 'Station': 12
# 'assign': 17
# 'Riverside': 10
# 'section': 132
# 'Rumford': 2
# 'Speaking': 14
# 'status': 96
# 'bet': 19
# 'hundred': 171
# 'know': 679
# 'enemy': 87
# 'Narragansett': 6
# 'Race': 3
# 'Track': 1
# 'grounds': 54
# 'assembly': 21
# 'point': 375
# 'drive-in': 4
# 'theater': 38
# 'Seekonk': 2
# 'knowing': 48
# 'assemble': 8
# 'air': 218
# 'Such': 111
# 'vital': 54
# 'frequently': 85
# 'regular': 79
# 'intervals': 25
# 'fails': 14
# 'consider': 106
# 'call': 181
# 'September': 56
# 'developed': 169
# 'things': 361
# 'classes': 76
# 'drifts': 3
# 'level': 212
# 'examine': 33
# 'revisions': 9
# 'Governor': 38
# 'Notte': 20
# 'name': 292
# 'move': 168
# 'form': 351
# 'letter': 140
# 'Miss': 232
# 'Mary': 87
# 'Grant': 12
# 'deputy': 10
# 'clerk': 34
# 'Falls': 9
# 'copy': 38
# 'released': 26
# 'responding': 6
# 'urges': 8
# 'complete': 179
# 'eye': 119
# 'legislature': 12
# 'Legislative': 1
# 'perform': 29
# 'review': 46
# 'Atty.': 4
# 'Gen.': 23
# 'Joseph': 55
# 'Nugent': 5
# 'views': 51
# 'appoint': 6
# 'Nugent's': 1
# 'expect': 107
# 'religious': 158
# 'labor': 119
# 'special-interest': 1
# 'affected': 36
# 'wrote': 181
# 'continuous': 41
# 'confronts': 5
# 'enforcement': 19
# 'officers': 81
# 'regulating': 4
# 'advised': 33
# 'enforce': 8
# 'Should': 23
# 'shirking': 2
# 'activity': 115
# 'across': 274
# 'statutes': 7
# 'Bay': 38
# 'dating': 4
# 'instances': 30
# 'colonial': 14
# 'times': 264
# 'severely': 16
# 'limit': 47
# 'types': 114
# 'merchandise': 6
# 'sold': 47
# 'Sabbath': 2
# 'concern': 97
# 'especially': 156
# 'foods': 42
# 'placed': 126
# 'list': 130
# 'neighborhood': 58
# 'grocery': 7
# 'variety': 84
# 'stores': 34
# 'chance': 129
# 'compete': 23
# 'supermarkets': 3
# 'council's': 2
# 'small': 518
# 'shops': 16
# 'retained': 22
# 'livelihood': 5
# 'thousands': 44
# 'declares': 11
# 'licenses': 5
# 'revenue': 19
# 'factory': 23
# 'outlets': 6
# 'operate': 48
# 'contended': 12
# 'shopping': 26
# 'Liberals': 5
# 'conservatives': 4
# 'parties': 58
# 'independent': 66
# 'Reama': 5
# 'nationally': 10
# 'known': 245
# 'labor-management': 7
# 'expert': 30
# 'Rotary': 5
# 'Club': 76
# 'luncheon': 23
# 'Sheraton-Biltmore': 3
# 'Hotel': 43
# 'type': 197
# 'enterprise': 31
# 'regrouping': 1
# 'average': 127
# 'voter': 3
# 'pull': 50
# 'lever': 13
# 'confessing': 3
# 'member': 133
# 'Socialist': 15
# '1910': 16
# 'That': 357
# 'machinist': 5
# 'toolmaker': 1
# 'fellow': 62
# 'grooming': 1
# 'me': 1165
# 'steered': 4
# 'utilities': 7
# 'pooling': 1
# 'resources': 72
# 'gaining': 13
# 'victory': 54
# 'original': 102
# 'retired': 34
# 'vice': 26
# 'Screw': 1
# '1955': 28
# 'us': 670
# 'gross': 26
# 'product': 83
# 'neither': 107
# 'favors': 10
# 'wage': 56
# 'increases': 69
# 'manufacturers': 40
# 'caught': 97
# 'profit': 28
# 'squeeze': 11
# 'conditioned': 20
# 'Indicating': 1
# 'turned': 320
# 'philosophy': 81
# 'dividing': 7
# 'everything': 162
# 'really': 267
# 'engaged': 46
# 'industrial': 114
# 'counseling': 9
# 'bearing': 25
# '1,700': 2
# 'Johnston': 21
# 'presented': 82
# 'town': 201
# 'obtaining': 9
# 'charter': 21
# 'Martinelli': 7
# 'Group': 9
# 'transferred': 29
# 'hand': 418
# 'suggestion': 34
# 'Fortin': 1
# 'Sr.': 7
# 'governs': 2
# 'referred': 45
# 'canvassers': 2
# 'happens': 40
# 'explained': 80
# 'assure': 37
# 'scheduling': 2
# '60': 46
# 'completes': 5
# 'difference': 148
# 'arose': 18
# 'Bourcier': 3
# 'solicitor': 3
# 'exact': 27
# 'handled': 26
# 'justices': 1
# 'favoring': 4
# 'assured': 39
# 'correct': 51
# 'strategy': 21
# 'movement': 124
# 'undoubtedly': 17
# 'comes': 133
# 'inspiring': 6
# 'think': 427
# 'hope': 164
# 'spearhead': 1
# 'surprised': 56
# 'running': 119
# 'non-partisan': 2
# 'posts': 22
# 'Our': 110
# 'goal': 60
# 'awareness': 32
# 'timetable': 4
# 'followed': 172
# 'started': 194
# 'town's': 14
# 'insurgent': 1
# 'speaking': 48
# 'model': 63
# 'municipal': 27
# 'league': 23
# 'Increasing': 3
# 'Misunderstanding': 1
# 'meaning': 124
# 'cited': 24
# 'false': 28
# 'pretenses': 1
# 'signers': 1
# 'affixed': 14
# 'consent': 16
# 'provision': 46
# 'included': 94
# 'Sanitary': 3
# 'sewer': 9
# 'Action': 4
# 'ordinance': 9
# 'motorists': 4
# 'plead': 5
# 'guilty': 29
# 'minor': 49
# 'traffic': 60
# 'offenses': 5
# 'fines': 2
# 'station': 93
# 'Monday's': 3
# 'Town': 11
# 'SanAntonio': 1
# 'Solicitor': 3
# 'Michael': 11
# 'Abatuno': 1
# 'draft': 16
# 'At': 409
# 'authorized': 37
# 'adopt': 13
# 'Nothing': 53
# 'Sixth': 6
# 'disposition': 13
# 'Local': 15
# 'hesitated': 21
# 'prosecute': 2
# 'heavy': 107
# 'simplest': 10
# 'offense': 8
# 'Plainfield': 3
# 'Mitchell': 26
# 'Walter': 40
# 'R-Bergen': 1
# 'value': 200
# 'using': 132
# 'remark': 31
# 'Campaigning': 1
# 'carcass': 7
# 'Republicanism': 4
# 'Dumont': 10
# 'R-Warren': 1
# 'spoke': 87
# '100': 77
# 'Park': 46
# 'controversial': 12
# 'Westfield': 6
# 'Young': 26
# 'cocktail': 24
# 'Scotch': 5
# 'Plains': 10
# 'Country': 12
# 'greeted': 20
# 'chorus': 17
# 'boos': 2
# '500': 16
# 'women': 182
# 'Trenton': 4
# 'forum': 7
# 'Federation': 12
# 'Women's': 12
# 'Clubs': 5
# 'intention': 36
# 'stopped': 129
# 'beating': 13
# 'lifeblood': 1
# 'congealed': 4
# 'Now': 269
# 'he's': 60
# 'gone': 190
# 'sell': 40
# 'tattered': 5
# 'remains': 84
# 'love': 214
# 'considered': 150
# 'mediocre': 5
# 'nothing': 358
# 'fall': 136
# 'common': 208
# 'decency': 10
# 'proud': 50
# 'adminstration': 1
# 'closeness': 1
# 'fall's': 1
# 'dead': 166
# 'Regrets': 1
# 'regretted': 11
# 'wrong': 128
# 'inject': 5
# 'waged': 7
# 'issues': 66
# 're-arguing': 1
# 'respond': 21
# 'either': 273
# 'applause': 14
# 'Hughes'': 2
# 'merit': 27
# 'open': 305
# 'launched': 21
# 'continuance': 6
# 'passenger': 14
# 'proper': 92
# 'uses': 58
# 'surplus': 27
# 'Jersey': 24
# 'attractive': 39
# 'industry': 161
# 'Decries': 1
# 'joblessness': 1
# 'decried': 2
# 'unemployment': 15
# 'Meyner': 3
# 'Republican-controlled': 1
# 'share': 95
# 'blame': 34
# 'Mack': 1
# 'Truck': 2
# 'plant': 122
# 'until': 433
# 'am': 225
# 'income': 97
# 'unhappy': 26
# 'minutes': 193
# 'saved': 43
# 'barbs': 2
# 'centralization': 4
# 'looks': 77
# 'Administration': 58
# 'transportation': 39
# 'crises': 21
# 'saying': 113
# 'ways': 126
# 'faced': 50
# 'motor': 53
# 'vehicles': 52
# 'challenge': 35
# 'stands': 65
# 'Defends': 2
# 'Ike': 4
# 'Earlier': 3
# 'resent': 8
# 'reference': 66
# 'discredited': 3
# 'president's': 5
# 'insult': 7
# 'twice': 66
# 'overwhelmingly': 7
# 'symbol': 54
# 'peace-loving': 2
# 'intentions': 22
# 'understand': 137
# 'seeking': 42
# 'position': 238
# 'life': 676
# 'demonstrate': 28
# 'judgment': 58
# 'bad': 139
# 'taste': 57
# 'vicious': 17
# 'origin': 42
# 'desire': 79
# 'try': 128
# 'condemning': 4
# 'stature': 15
# 'rebound': 2
# 'discredit': 2
# 'Sees': 1
# 'ahead': 106
# 'Sandman': 5
# 'R-Cape': 1
# 'May': 110
# 'opponents': 12
# 'nomination': 12
# 'addressing': 9
# 'Military': 16
# 'Newark': 8
# 'Essex': 12
# 'leaders': 106
# 'managers': 24
# 'gathering': 27
# 'indicate': 80
# 'chosen': 71
# 'Party's': 1
# 'nominee': 3
# 'majority': 57
# 'announcement': 24
# 'Clifford': 5
# 'Case': 7
# 'spend': 53
# 'campaigning': 3
# 'giveaway': 4
# 'desperate': 26
# 'prop': 4
# 'sagging': 4
# 'proven': 11
# 'answer': 149
# 'Jersey's': 2
# 'witnessed': 13
# 'image': 117
# 'failed': 74
# 'witnessing': 6
# 'transfer': 38
# 'glow': 15
# 'Case's': 1
# 'candidacy': 6
# 'fail': 37
# 'Harriet': 9
# 'Copeland': 2
# 'Greenfield': 2
# '330': 2
# 'Woodland': 1
# 'Ave.': 13
# 'Women': 13
# 'committeewoman': 2
# 'Supervisor': 2
# 'Weldon': 1
# 'Sheets': 4
# 'paper': 153
# 'ballots': 2
# 'represents': 39
# 'necessary': 221
# 'democracy': 22
# 'lip': 18
# 'financing': 32
# 'purchase': 43
# 'machines': 52
# 'repay': 7
# '10-year': 9
# 'exclusive': 27
# 'January': 53
# '1964': 3
# 'Although': 123
# 'mandatory': 6
# 'impinging': 5
# 'basically': 18
# 'distasteful': 1
# 'results': 141
# 'transcended': 1
# 'Sheeran': 3
# 'Orange': 7
# 'Edward': 45
# 'Roos': 2
# 'safety': 45
# 'commissioner': 6
# 'FBI': 8
# 'organization's': 3
# 'Freeholder': 1
# 'MacDonald': 2
# 'vacancy': 4
# 'Neil': 3
# 'Duffy': 2
# 'Appeals': 6
# 'My': 157
# 'experience': 272
# 'shown': 166
# 'filled': 99
# 'preferably': 13
# 'Jim': 36
# 'fits': 13
# 'description': 53
# 'Seidel': 2
# 'warden': 4
# 'Conservation': 6
# '36': 10
# 'citation': 5
# 'Commissioner': 13
# 'Salvatore': 1
# 'Bontempo': 2
# 'credits': 7
# 'supervision': 19
# 'reduction': 41
# 'forest': 40
# 'fires': 16
# '1925': 9
# 'division': 66
# 'graduation': 11
# '1921': 8
# 'Michigan': 21
# 'forestry': 1
# 'private': 186
# 'lumber': 30
# 'October': 51
# '1944': 15
# 'Forest': 26
# 'Section': 57
# 'fire-fighting': 2
# 'techniques': 98
# 'plowing': 11
# 'established': 108
# 'tractor': 22
# 'plows': 3
# 'units': 87
# 'expanded': 20
# 'modernized': 3
# 'central': 106
# 'briefing': 2
# 'wardens': 2
# 'training': 146
# 'credited': 12
# 'co-operative': 5
# 'co-operation': 12
# 'Cross': 11
# 'Boonton': 1
# 'debut': 14
# 'bid': 21
# 'pledge': 2
# 'corner': 113
# 'nearly': 134
# 'Puddingstone': 1
# 'Inn': 4
# 'you'll': 60
# 'You're': 58
# 'you're': 93
# 'we're': 35
# 'glad': 36
# 'Democrats': 40
# 'resolve': 12
# 'expedient': 7
# 'Attacks': 2
# 'tripping': 2
# 'feet': 283
# 'popular': 96
# 'slogans': 5
# 'win': 55
# 'we'll': 26
# 'liberal': 61
# 'planned': 72
# 'forward': 115
# 'looking': 162
# 'honest': 45
# 'We'll': 38
# 'talk': 151
# 'mouth': 103
# 'truth': 124
# 'elect': 8
# 'signs': 66
# 'Republicans'': 1
# 'feeble': 8
# 'shall': 254
# 'full': 225
# 'partner': 32
# 'courageous': 4
# 'attraction': 15
# 'stop': 110
# 'piracy': 1
# 'Southern': 109
# 'keep': 247
# 'bloodstream': 4
# 'clean': 64
# 'To': 426
# 'hoodlums': 3
# 'infiltrating': 1
# '1940s': 1
# 'Calling': 1
# 'lives': 80
# 'breathes': 2
# 'representative': 40
# 'springboard': 2
# 'Meyner's': 1
# 'Green': 22
# 'Acres': 2
# 'tracts': 5
# 'land': 199
# 'onrush': 4
# '$60': 6
# 'underwrite': 3
# '$45': 4
# '$15': 5
# 'alloted': 1
# 'municipalities': 9
# 'conquer': 4
# 'space': 171
# 'conserve': 3
# 'pointing': 26
# '125,000': 1
# '1950': 21
# 'rapidly': 65
# 'changing': 40
# 'unless': 88
# 'preserve': 34
# 'green': 94
# 'comment': 41
# 'misconstrued': 2
# 'sympathetic': 35
# 'I'll': 181
# 'explicit': 23
# 'bring': 156
# 'dynamic': 21
# 'afraid': 55
# 'tangle': 8
# 'Fifteen': 8
# 'retiring': 7
# 'voluntarily': 9
# 'honored': 24
# 'colleagues': 23
# 'whose': 250
# 'four-year': 3
# 'terms': 160
# 'expire': 1
# 'carved': 14
# 'wooden': 49
# 'elephants': 10
# 'ivory': 16
# 'tusks': 3
# 'remember': 120
# 'retirements': 1
# 'leaving': 80
# 'presentation': 32
# 'Geraldine': 2
# 'Thompson': 38
# 'Bank': 29
# 'stepping': 9
# 'She': 911
# '1920s': 4
# 'adoption': 10
# 'women's': 15
# 'suffrage': 5
# 'Resentment': 1
# 'welled': 1
# 'Wagner': 21
# 'Paul': 38
# 'Screvane': 3
# 'Abraham': 6
# 'Beame': 3
# 'mates': 10
# 'same': 679
# 'anti-organization': 2
# 'Liberal': 8
# 'Mayor's': 4
# 'opportunity': 120
# 'internal': 47
# 'resentment': 17
# 'regarded': 55
# 'bigger': 34
# 'Opposition': 1
# 'trying': 162
# 'induce': 9
# 'Controller': 8
# 'Arthur': 51
# 'Levitt': 4
# 'Brooklyn': 29
# 'Mayoral': 1
# '7': 94
# 'contend': 6
# 'file': 75
# 'Their': 107
# 'view': 183
# 'last-minute': 2
# 'proposing': 6
# 'ticket': 16
# 'emphasize': 20
# 'weakness': 45
# 'performance': 122
# 'rival': 11
# 'slate': 5
# 'Representative': 7
# 'Buckley': 7
# 'Bronx': 9
# 'T.': 27
# 'Sharkey': 1
# 'visits': 17
# 'usual': 96
# 'touch': 86
# 'Carmine': 2
# 'G.': 42
# 'Sapio': 3
# 'Manhattan': 20
# 'publicly': 26
# 'believing': 12
# 'replaced': 42
# 'Last': 40
# 'visited': 41
# 'leader's': 6
# 'discussion': 89
# 'Apparently': 21
# 'key': 81
# 'acceptance': 48
# 'choices': 12
# 'struggle': 62
# 'talks': 18
# 'assent': 4
# 'dropping': 15
# 'Gerosa': 2
# 'seems': 252
# 'assumed': 72
# 'pick': 52
# 'Gerosa's': 2
# 'successor': 16
# 'declined': 17
# 'interviews': 17
# 'reporters': 32
# 'confirm': 16
# 'deny': 47
# 'Queens': 3
# 'replace': 29
# 'Abe': 3
# 'Stark': 3
# 'incumbent': 2
# 'Irish': 28
# 'Counties': 4
# 'Feis': 1
# 'Hunter': 12
# 'Campus': 3
# 'published': 85
# 'yesterday's': 6
# 'Times': 36
# 'announce': 18
# 'definite': 36
# 'June': 99
# '16': 54
# 'wave': 46
# 'corruption': 13
# 'tangible': 19
# 'feeling': 168
# 'revulsion': 6
# 'taxi': 16
# 'driver': 48
# 'visitor': 13
# 'remarks': 48
# 'politicians': 19
# 'It's': 160
# 'See': 44
# 'scientist': 17
# 'writes': 40
# 'alienated': 6
# 'influence': 132
# 'corrupt': 8
# 'selfish': 8
# 'beyond': 157
# 'secret': 77
# 'conspiracy': 22
# 'object': 64
# 'plunder': 2
# 'Corruption': 1
# 'widely': 52
# 'identified': 46
# 'locale': 3
# 'Edwin': 11
# 'O'Connor's': 1
# 'novel': 59
# 'Hurrah': 3
# 'reasons': 102
# 'spotlight': 6
# 'succession': 18
# 'publicized': 6
# 'scandals': 7
# 'aroused': 19
# 'Graft': 1
# 'works': 122
# 'investigations': 21
# 'attracted': 25
# 'ethical': 29
# 'reader': 43
# 'newspapers': 37
# 'escape': 61
# 'petty': 6
# 'chicanery': 1
# 'worse': 48
# 'norm': 7
# 'Day': 64
# 'episode': 12
# 'Public': 37
# 'Works': 8
# 'accused': 25
# '$8,555': 1
# 'beach': 33
# 'waterfront': 10
# 'sharply': 38
# 'contrasting': 11
# 'forecasts': 5
# 'Southern-Republican': 1
# 'Administration's': 3
# 'jockeying': 1
# 'aid-to-education': 1
# 'Rules': 9
# 'uncertain': 22
# 'panel's': 1
# 'depends': 49
# 'Trimble': 3
# 'Democrat': 13
# 'siding': 5
# 'Rayburn's': 8
# 'Leadership': 3
# 'hopeful': 12
# 'encounter': 28
# 'sometime': 9
# '$6,100,000,000': 1
# 'provides': 81
# 'forty-year': 1
# 'mortgages': 5
# 'low': 160
# 'down-payments': 1
# 'moderate-income': 1
# 'families': 64
# 'slums': 7
# 'colleges': 39
# 'dormitories': 4
# 'appears': 84
# 'temporarily': 20
# 'stalled': 4
# 'Northern': 24
# 'usually': 189
# 'balking': 1
# 'Delaney': 3
# 'Thomas': 100
# 'O'Neill': 3
# 'Three': 57
# 'quick': 66
# 'progress': 109
# 'amending': 1
# 'Act': 116
# 'long-term': 31
# 'loans': 29
# 'parochial': 12
# 'private-school': 1
# 'science': 105
# 'languages': 39
# 'mathematics': 18
# 'public-school': 2
# 'clears': 1
# 'About': 49
# 'Peace': 65
# 'assigned': 53
# 'agencies': 61
# 'carried': 124
# 'corps': 26
# '$40,000,000': 1
# 'submitted': 21
# ...
# 'nobody'd': 1
# 'Christians'': 2
# 'good-living': 1
# 'Lucille's': 1
# 'trucker': 1
# 'folks'': 1
# 'crackling': 1
# 'smokes': 1
# 'ticking': 1
# 'swears': 1
# 'noncommittally': 1
# 'fierceness': 1
# 'Astonishingly': 1
# 'Mmm': 2
# 'contentment': 1
# 'Idiot's': 1
# 'upbringing': 1
# 'Johnnie's': 1
# 'petted': 2
# 'husband-stealer': 1
# 'wondrous': 1
# 'Faneuil': 1
# 'Alma': 6
# 'pumpkin': 1
# 'Schmalma': 1
# 'ale': 1
# ''most': 1
# 'lubricated': 1
# 'all-American-boy': 1
# 'Astronaut': 1
# 'two-burner': 1
# 'lunatic': 1
# 'bachelor-type': 1
# 'eatables': 1
# 'Kirby's': 3
# 'vitamin-and-iron': 1
# 'Vivian': 11
# 'scalded': 1
# 'Woods': 1
# 'mockery': 2
# 'odds-on': 1
# 'black-and-yellow': 1
# 'polka-dotted': 1
# 'Three-day': 1
# 'Pyhrric': 1
# 'bake': 2
# 'forbore': 1
# 'Peony': 3
# 'honeymooning': 1
# 'what's-his-name': 3
# 'unalloyed': 1
# 'leafed': 1
# 'Bobbsey': 2
# 'hoof-and-mouth': 1
# 'long-hair': 1
# 'squirt': 1
# 'Kissin'': 1
# 'Kare': 1
# 'swiping': 1
# 'Ugh': 1
# 'fast-frozen': 1
# 'horse-blanket': 1
# 'plaid': 1
# 'splashy': 1
# 'toilsome': 1
# 'clattery': 1
# 'mops': 1
# 'rain's': 1
# 'scorcher': 1
# 'Larkspur': 2
# 'kind's': 1
# 'Run-down': 1
# 'iron-poor': 1
# 'Frail': 1
# 'varicolored': 1
# 'floodlit': 1
# 'flower's': 1
# 'M-m-m': 1
# 'ninety-six': 2
# 'redheads': 1
# 'browny': 1
# 'browny-haired': 2
# 'blondes': 1
# 'bikinis': 1
# 'dune': 1
# 'turtle-neck': 1
# 'not-so-pale': 1
# 'moonlit': 2
# 'filched': 1
# 'goodness'': 1
# 'Vivian's': 1
# 'pajama': 1
# 'Correspondence': 1
# 'whitens': 1
# 'Broiled': 1
# 'Puny': 1
# 'Surviving': 1
# 'Speedy': 1
# 'Canoe': 1
# 'Anniston's': 1
# 'Riverside's': 1
# 'redheaded': 1
# 'Rossoff': 6
# 'Deegan's': 2
# 'Deegan': 22
# 'punches': 1
# 'dugout': 7
# 'sonny': 1
# 'Mind': 1
# 'fielder's': 1
# 'catcher's': 1
# 'ballplayers': 3
# 'hander': 1
# 'hefty': 1
# 'batter's': 1
# 'Ricco': 4
# 'Phil's': 2
# 'Haydon': 1
# 'flat-footed': 1
# 'Fights': 1
# 'squelched': 1
# 'sweatshirt': 2
# 'helluva': 1
# 'team-mate': 1
# 'Eddie's': 1
# 'pro-ball': 1
# 'Dazed': 1
# 'Baseball's': 1
# 'ramming': 1
# 'goddamit': 1
# 'Springfield's': 1
# 'outfielders': 1
# 'by-ways': 1
# 'Lao-tse': 1
# 'Mencius': 1
# 'Suzuki': 1
# 'tomes': 1
# 'Krishnaists': 1
# 'socio-archaeological': 1
# 'Zend-Avesta': 1
# 'Acala': 5
# 'Grinned': 1
# 'bookish': 1
# 'biwa': 9
# 'incarcerated': 1
# 'dusted': 1
# 'tea-drinking': 1
# 'Ryusenji': 8
# 'Fudomae': 3
# 'Charlotte's': 3
# 'flippant': 1
# 'pointless': 1
# 'Soba': 1
# 'udon': 1
# 'Sushi': 1
# 'Sashimi': 1
# 'Ceecee': 2
# 'Witter': 1
# 'Gompachi': 1
# 'Komurasaki': 1
# 'parkish': 1
# 'Kanto': 1
# 'Fudo': 7
# 'bothersome': 1
# 'ascetic': 1
# 'spigots': 1
# 'caged': 1
# 'limpid': 1
# 'fountain-falls': 1
# 'hundred-yen': 1
# 'Fudo's': 2
# 'stubble': 2
# 'snow-fence': 1
# 'lath': 2
# 'furrow': 5
# 'multi-colored': 1
# 'delicately': 2
# 'jet-black': 1
# 'fire-colored': 1
# 'forepart': 1
# 'fieldmice': 1
# 'newly-plowed': 1
# 'sun-burned': 1
# 'paleness': 1
# 'uncolored': 1
# 'plowshares': 1
# 'frenzied': 1
# 'hunched-up': 1
# 'frenetic': 1
# 'savagery': 1
# 'bubbly': 1
# 'finely-spun': 1
# 'effeminate': 1
# 'eyelashes': 1
# 'brushlike': 1
# 'newly-scrubbed': 1
# 'Snakes': 3
# 'gray-looking': 1
# 'beautifully-tapered': 1
# 'vise': 1
# 'splayed': 1
# 'thickest': 1
# 'ice-feeling': 1
# 'tool-kit': 1
# 'gleeful': 1
# 'glee': 1
# 'Cady': 27
# 'unglued': 1
# 'Hanford': 16
# 'alma': 1
# 'mater': 1
# 'snapper': 1
# 'Partlow': 9
# 'reunions': 1
# 'old-grad-type': 1
# 'Pete's': 1
# 'politicking': 1
# 'Height': 1
# '6'': 1
# 'Weight': 1
# 'enrolling': 1
# 'ruining': 1
# 'soul-searching': 1
# 'unsealed': 1
# 'gasser': 1
# 'pre-packed': 1
# 'messing': 1
# 'unease': 1
# 'Weakness': 1
# 'surcease': 1
# 'navy-blue': 1
# 'shag': 1
# 'Partlow's': 1
# 'Hear': 2
# 'straight-A': 1
# 'antisocial': 2
# 'book-lined': 1
# 'Wrong': 1
# 'Dave's': 1
# 'play-off': 1
# 'Astronomy': 1
# 'fishpond': 1
# 'Crazy': 2
# 'Colts': 2
# 'mollified': 1
# 'ham-radio': 1
# 'hemming': 1
# 'well-worn': 1
# 'mailbox': 1
# 'patina': 1
# 'vertebrae': 1
# 'unyielding': 1
# 'invigorating': 1
# 'neatness': 1
# 'incongruity': 1
# 'Quietly': 1
# 'Anthea': 3
# 'glissade': 1
# 'ellipsis': 1
# 'Brainards': 1
# 'fumed': 1
# 'titters': 1
# 'whisperings': 1
# 'scabrous': 1
# 'gossiping': 1
# 'hoarseness': 1
# 'Angrily': 1
# 'bedroom's': 1
# 'scattering': 1
# 'Bizarre': 1
# 'Alternately': 1
# 'defeatism': 1
# 'Instantaneously': 1
# 'panties': 1
# 'unruly': 1
# 'underclothes': 1
# 'nylon': 1
# 'Extending': 1
# 'A-Z': 5
# 'nibs'': 1
# 'Hershey's': 1
# 'Eddyman': 1
# 'Freddy': 20
# 'Gerry': 4
# 'Willis': 16
# 'Zenith': 5
# 'vicissitudes': 1
# 'Freddy's': 4
# 'prospering': 1
# 'competency': 1
# 'Willis'': 2
# 'calculators': 1
# 'Herberet': 3
# 'coffers': 1
# 'Allstates': 4
# 'medium-sized': 1
# 'four-wheel-drive': 1
# 'off-road': 1
# 'over-large': 1
# 'Cursed': 1
# 'amalgamation': 1
# 'Herberet's': 1
# 'Allstates'': 1
# 'sub-assembly': 1
# 'ordnance': 1
# 'complaisant': 1
# 'Hamrick': 8
# 'compound-engine': 1
# 'Richert': 5
# 'dampening': 1
# 'fray': 1
# 'patriarchy': 1
# 'closeted': 1
# 'A-Z's': 1
# 'Hamrick's': 2
# 'coincidental': 1
# 'out-dated': 1
# 'small-car': 1
# 'Ticonderoga': 4
# 'broach': 1
# 'dealerships': 1
# 'gantlet': 2
# 'incredulity': 1
# 'low-priced': 1
# 'chromed': 1
# 'too-expensive': 1
# 'Allstates-Zenith': 1
# 'Heads': 1
# 'availing': 1
# 'disquietude': 1
# 'Spike-haired': 1
# 'red-faced': 1
# 'decked': 1
# 'horn-rimmed': 1
# 'Hinkle': 1
# 'Barco': 18
# 'fancying': 1
# 'Beard': 1
# 'instigation': 1
# 'Barco's': 8
# 'Cal': 1
# 'Ye': 1
# 'Olde': 1
# 'Gasse': 1
# 'Avocado': 1
# 'Capistrano': 1
# 'By-the-Sea': 1
# 'Drive-in': 1
# 'tamale': 1
# 'Glendale': 1
# 'unhinged': 1
# 'fainted': 1
# 'lifelong': 1
# 'Welch': 14
# 'mayorship': 1
# 'Welch's': 6
# 'shifty': 1
# 'pooh-poohed': 1
# 'Ridiculous': 1
# 'cameramen': 1
# 'matter-of-factness': 1
# 'cortege': 1
# 'Stopping': 1
# 'shrub-covered': 1
# 'quibs': 1
# 'gibes': 1
# 'digger': 2
# 'murderer's': 1
# 'cahoots': 1
# 'Marshall's': 1
# 'Viola': 11
# 'Viola's': 4
# 'Romances': 1
# 'Addict': 1
# 'Downfall': 1
# 'Idol': 1
# 'overvaulting': 1
# 'luckier': 1
# 'unidentified': 1
# 'prank': 1
# 'Southland': 1
# 'footwear': 1
# 'commiserate': 1
# 'Scandal': 2
# 'snobbishly': 1
# 'Czarship': 1
# 'Angeles-Pasadena': 1
# 'scions': 1
# 'Budweisers': 1
# 'Chalmers': 1
# 'Heinzes': 1
# 'pickles': 1
# 'midsts': 1
# 'Pickfair': 1
# 'Doug': 1
# 'hoi-polloi': 1
# 'trump': 1
# 'matrimonial': 1
# 'chi-chi': 1
# 'cosy': 1
# 'chaperon': 1
# 'hotbed': 1
# 'ladle': 1
# 'cook's': 1
# 'giblet': 1
# 'asparagus': 1
# 'sprig': 1
# 'creamed': 1
# 'Beige's': 1
# 'Jennie': 3
# 'remoter': 1
# 'Jennie's': 1
# 'Miranda's': 1
# 'screeches': 1
# 'thuds': 1
# 'gainer': 1
# 'Resolving': 1
# 'woolgather': 1
# 'Catatonia': 7
# 'Parvenu': 2
# 'heiress': 1
# 'dabbler': 1
# 'honeymooned': 2
# 'suburbia': 1
# 'gourmet's': 1
# 'nonconformist': 1
# 'knee-length': 2
# 'plaids': 1
# 'SS.': 1
# 'Fran's': 1
# 'Baccarat': 1
# 'marinated': 1
# 'Koussevitzky's': 1
# 'marshmallows': 1
# 'ruefulness': 1
# 'souffle': 1
# 'red-blooded': 1
# 'valueless': 1
# 'astringency': 1
# 'Grazie': 4
# 'Gwen': 1
# 'Cafritz': 1
# 'Francesca's': 1
# 'Perle': 1
# 'Mesta': 1
# 'rivals': 1
# 'unfunnily': 1
# 'sarcastic': 1
# 'ultra-modern': 1
# 'housepaint': 1
# 'hair-trigger': 1
# 'zounds': 2
# 'country-squirehood': 1
# 'too-hearty': 1
# 'misty-eyed': 1
# 'unadulterated': 1
# 'mistrusted': 2
# 'Shops': 1
# 'Pioneers': 1
# 'homesteads': 1
# 'pioneers': 2
# 'gardeners': 1
# 'parent-teacher': 1
# '$85,000': 1
# 'Daphne': 1
# 'Maurier': 1
# 'Kafka': 5
# 'Reverently': 1
# 'Becoming': 1
# 'Bananas': 1
# 'devil's-food': 1
# 'icing': 1
# 'snoop': 1
# 'coast-to-coast': 1
# 'pre-empting': 1
# 'Cantor': 2
# 'Merry-go-round': 1
# 'Bowes': 1
# 'larder': 1
# 'ransacking': 1
# 'barbarian': 1
# 'Metronome': 2
# 'sacking': 1
# 'despoiling': 1
# 'Bolshevistic': 1
# 'iniquitous': 1
# 'Morris'': 1
# 'relict': 1
# 'stung': 2
# 'hard-come-by': 1
# 'leftist': 1
# 'availed': 2
# 'tigress': 1
# 'toadies': 1
# 'sycophants': 1
# 'Portia': 1
# 'grata': 1
# 'Poitrine's': 2
# 'Belle': 1
# 'Poitrine': 3
# 'Caligula': 1
# 'Nineveh': 1
# 'prohibitive': 1
# 'usurious': 1
# 'notoriety': 1
# 'baroness': 1
# 'traitor': 1
# 'Traitor': 1
# 'ere': 1
# 'Minute': 1
# 'Fascio-Communist': 1
# 'NRA': 1
# 'PWA': 1
# 'WPA': 1
# 'CCC': 1
# 'imperilled': 1
# 'distractions': 1
# 'unflagging': 1
# 'stardom': 2
# 'Letch': 19
# 'thespians': 1
# 'co-star': 1
# 'helpmate': 1
# 'sulks': 1
# 'storming': 1
# 'Letch's': 2
# 'dislocated': 1
# 'monies': 1
# 'gaming': 1
# 'bookies': 2
# 'commonest': 1
# 'ungallant': 1
# 'Baby-dear': 2
# 'Belletch': 2
# 'Feeley': 3
# 'slights': 1
# 'Trianon': 1
# 'collation': 1
# 'overcooked': 1
# 'Aquacutie': 1
# 'Epiphany': 1
# 'Errol': 1
# 'Flynn's': 1
# 'starlet': 2
# 'Filmdom': 1
# 'Astaires': 1
# 'Colmans': 1
# 'Rathbones': 1
# 'Taylors': 1
# 'Thalbergs': 1
# 'Barrymores': 1
# 'Crosbys': 1
# 'screenland': 1
# 'Sainted': 1
# 'Cabrini': 4
# 'beatification': 1
# 'dens': 1
# 'deigned': 1
# 'tasteless': 1
# 'unfunny': 1
# 'over-spent': 1
# 'farmed': 1
# 'Diet': 1
# 'Worms': 1
# 'Gauntley': 1
# 'Marquess': 1
# 'inherits': 1
# 'moors': 1
# 'unbeknownst': 1
# 'shoestring': 1
# 'unrepentant': 1
# 'Momma': 2
# 'Bookies': 1
# 'make-ready': 1
# 'romping': 1
# 'yelping': 1
# 'fret': 1
# 'perfectionists': 1
# 'polishing': 2
# 'lizards': 1
# 'dial': 1
# 'Bradley's': 1
# 'Hardware': 1
# 'carpenter's': 1
# 'babbiting': 1
# 'doweling': 1
# 'pegboard': 6
# 'workbench': 8
# 'sandpaper': 1
# 'Jinny': 1
# 'two-by-fours': 1
# 'Crombie': 11
# 'assortment': 1
# 'Crumb': 3
# 'worktable': 1
# 'handyman-carpenter': 1
# 'Carpenters': 1
# 'Blatz': 9
# 'Smithtown': 1
# 'Crombie's': 1
# 'Highfield': 1
# 'Blatz's': 1
# 'pegboards': 2
# 'shipshape': 1
# ''ceptin'': 1
# 'contraptions': 1
# 'Doors': 1
# 'Ambiguity': 3
# 'Brinsley': 1
# 'rhetoricians': 1
# 'amphibology': 1
# 'parisology': 1
# 'ologies': 1
# 'misinterpreters': 1
# 'misunderstanders': 1
# 'misdirectors': 1
# 'baffle': 1
# 'interweaving': 1
# 'jest': 1
# 'sours': 1
# 'non-repetitious': 1
# 'girl-friend': 1
# 'misquoted': 1
# 'stumped': 1
# 'biter': 1
# 'grammarians': 1
# 'wooden-leg': 1
# 'gagwriters': 1
# 'gagline': 1
# 'snapshots': 1
# 'Classified': 1
# 'chockfull': 1
# 'misrelated': 1
# 'Shapes': 1
# 'bathtubs': 1
# 'Couple': 1
# 'modifiers': 2
# 'headlinese': 1
# 'schooldays': 1
# 'caterer's': 1
# 'semi-ambiguous': 1
# 'journalese': 2
# 'gags': 2
# 'rumpus': 1
# 'Strangely': 1
# 'lumbar': 1
# 'misconstructions': 1
# 'anatomicals': 1
# 'gourmet': 2
# 'demurred': 1
# 'double-entendre': 2
# 'saleslady': 3
# 'Madam': 1
# 'woolly-minded': 1
# 'indefinity': 1
# 'clergyman's': 1
# 'Dearly': 1
# 'So-so': 1
# 'maxim': 1
# 'Indefinite': 1
# 'double-meaning': 1
# 'undertaker': 1
# 'soulfully': 1
# 'Replies': 1
# 'equivocal': 1
# 'it-wit': 1
# 'It-wit': 1
# 'misnomer': 1
# 'Moreland': 17
# 'Anglo-American': 2
# 'fairy-tale': 1
# 'Upson': 1
# 'peacocks': 3
# 'careerism': 1
# 'bee's': 1
# 'Horror': 1
# 'Comics': 1
# 'Zeitgeist': 1
# 'loon': 1
# 'hare': 1
# 'manic': 2
# 'paraphrasing': 1
# 'paraphrase': 2
# 'walrus': 1
# 'dooms': 1
# 'commoners': 1
# 'Traits': 1
# 'Foreigners': 2
# 'non-books': 1
# 'non-writers': 1
# 'non-publishers': 1
# 'non-readers': 1
# 'non-fiction': 3
# 'nonism': 1
# 'sit-down': 1
# 'noisier': 1
# 'non-English': 1
# 'Cryptic': 1
# 'Angst': 2
# 'retrogressive': 1
# 'Dilys': 1
# 'beholds': 1
# 'daffodils': 1
# 'Galahad': 1
# 'knightly': 1
# 'Longfellow': 1
# 'co-existence': 1
# 'co-extinction': 1
# 'theatres': 1
# 're-explore': 1
# 'antic': 1
# 'drawing-rooms': 1
# 'Anglo-Americans': 1
# 'tragicomic': 1
# 'brothel': 1
# 'dustbin': 1
# 'living-room': 1
# 'Furiouser': 1
# 'furiouser': 1
# 'clinked': 1
# 'Toujours': 1
# 'gai': 1
# 'Marquis'': 1
# 'Mehitabel': 1
# 'non-institutionalized': 1
# 'saner': 1
# 'ba-a-a': 1
# 'non-nonsense': 1
# 'Rhinoceros': 1
# 'rhinos': 2
# 'Non-God': 1
# 'anti-personality': 1
# 'Wynn': 1
# 'non-God': 1
# 'restively': 1
# 'fancy-free': 1
# 'screw-loose': 1
# 'frenzy-free': 1
# 'tube-nosed': 1
# 'disbelieves': 1
# 'Eddies': 1
# 'frog-eating': 1
# 'Gott': 1
# 'strafe': 2
# 'Angleterre': 1
# 'Carthago': 1
# 'delenda': 1
# 'Deus': 1
# 'Carthage': 1
# 'ideologist': 1
# 'paranoiac': 1
# 'manic-depressive': 1
# 'corrupts': 1
# 'nooks': 1
# 'non-poetry': 1
# 'Burnside's': 4
# 'policeman's': 1
# 'tumbles': 1
# 'unco-operative': 1
# 'twirlingly': 1
# 'somersaults': 2
# 'warm-up': 1
# 'cooked-over': 1
# 'oatmeal': 1
# 'gaspingly': 1
# 'funnier': 1
# 'Minks': 1
# 'chorused': 1
# 'Arlene's': 1
# 'bangish': 1
# 'radish': 8
# 'finger-held': 1
# 'ladylike': 1
# 'somersaulting': 1
# 'pamper': 1
# 'middles': 1
# 'laughingly': 1
# 'Gorboduc': 7
# 'ceremonially': 1
# 'horselike': 1
# 'balkiness': 1
# 'coconut-containing': 1
# 'convulsed': 1
# 'wheezes': 1
# 'over-pretended': 1
# 'perpetration': 1
# 'rakishly': 1
# 'rollickingly': 1
# 'eye-beamings': 1
# 'Pueri': 1
# 'aquam': 1
# 'silvas': 1
# 'agricolas': 1
# 'portant': 1
# 'vignette': 1
# 'pre-Punic': 1
# 'fifty-third': 1
# 'affianced': 1
# 'cancels': 1
# 'buckling': 1
# 'scimitar': 1
# 'stumbles': 1
# 'Opera's': 1
# 'Spumoni's': 1
# 'Sevigli': 1
# 'del': 1
# 'Spegititgninino': 1
# 'contralto': 1
# 'Hattie': 1
# 'Sforzt': 1
# 'Prometheus': 1
# 'Leather': 1
# 'Conduit': 1
# 'Hubba': 1
# 'hubba': 1
# 'Yalagaloo': 1
# 'overture': 1
# 'Ranavan': 1
# 'armadillo': 2
# 'atonally': 1
# 'Grunnfeu': 1
# 'Arapacis': 2
# 'Serbantian': 1
# 'invocation': 1
# 'Phineoppus': 1
# 'Gorshek': 1
# 'symbolizing': 2
# 'Lust': 1
# 'vanishes': 1
# 'Shuz': 1
# 'sidesteps': 1
# 'gooshey': 1
# 'ad-lib': 1
# 'Dharma': 1
# 'Eurasian': 1
# 'proto-senility': 1
# 'visrhanik': 1
# 'bantered': 1
# 'bouanahsha': 1
# 'salivate': 1
# 'pratakku': 1
# 'sweathruna': 1
# 'tongue-twister': 1
# 'nnuolapertar-it-vuh-karti-birifw-': 1
# 'Bathar-on-Walli': 1
# 'Province': 1
# 'spouting': 1
# 'Pockmanster's': 1
# 'Neitzbohr': 4
# 'Jungian': 1
# 'Meinckian': 1
# 'Wilhelmina': 2
# 'flashback': 1
# 'middle-Gaelic': 1
# 'derivations': 1
# 'slat': 2
# 'Reichstag': 1
# 'expunge': 1
# 'punishing': 1
# 'shatters': 1
# 'much-needed': 1
# 'movie-goer': 1
# 'Bini': 1
# 'SalFininistas': 2
# 'Ab63711-r': 1
# 'Brest-Silevniov': 1
# 'purgatory': 1
# 'Schlek': 2
# 'Neurenschatz': 1
# 'Skolkau': 1
# 'Baslot': 2
# 'Rattzhenfuut': 1
# 'Tschilwyk': 1
# 'flautist': 1
# 'Haumd': 1
# 'Haumd's': 1
# 'F-major': 1
# 'fingerings': 1
# 'flautist's': 1
# 'heavy-handed': 1
# 'inspirational': 1
# 'non-dramas': 1
# 'bittersweet': 1
# 'theatregoer': 1
# 'Basho's': 1
# 'frog-haiku': 1
# 'Entwhistle': 1
# 'amateurishness': 1
# 'offbeat': 1
# 'intruding': 1
# 'lemon-meringue': 1
# 'muffins': 1
# 'Rilke': 1
# 'unpretentious': 1
# 'Aging': 1
# 'enfant': 1
# 'Francoisette': 1
# 'Lagoon': 2
# 'scenario': 1
# 'Lascivious': 1
# 'Interlude': 1
# 'trip-hammer': 1
# 'pithy': 1
# 'all-pervading': 1
# 'hollowness': 1
# 'Mlle': 1
# 'Petite': 1
# 'Chadroe': 1
# 'engagingly': 1
# 'Bambi': 1
# 'Fink's': 1
# 'understated': 1
# 'Quizzical': 1
# 'Salamander': 1
# 'salamander': 1
# 'Alicia': 4
# 'tragically': 1
# 'Parkinson's': 1
# 'mah-jongg': 1
# 'Fing': 2
# 'Pulova': 2
# 'Hardwicke': 1
# 'Nabisco': 1
# 'bout-de-souffle': 1
# 'leitmotiv': 1
# 'Mudugno': 1
# 'Volare': 1
# 'opalescent': 1
# 'fascinatingly': 1
# 'Rosalie': 1
# 'beat-up': 1
# 'jeunes': 1
# 'Cause': 1
# 'pug-nosed': 1
# 'Jean-Pierre': 1
# 'Bravado': 2
# 'Bogartian': 1
# 'Tasti-Freeze': 1
# 'New-Waver': 1
# 'Fredrico': 1
# 'Rossilini's': 1
# 'Sour': 1
# 'Sponge': 1
# 'crackles': 1
# 'Soaring': 1
# 'Margo': 1
# 'Felicity': 1
# 'Brighetti': 1
# 'curvaceously': 1
# 'drib-drool': 1
# 'sophisticates': 1
# 'Expressionism': 1
# 'Vindication': 1
# 'Quasimodo's': 2
# 'Guggenheim': 1
# 'Quasimodo': 3
# 'Kandinsky': 1
# 'blossomed': 1
# 'Kline': 1
# 'inexpressible': 1
# 'unpaintable': 1
# 'non-time': 1
# 'unwaivering': 1
# 'Invasion': 1
# 'non-color': 1
# 'chiding': 1
# 'jocose': 1
# 'reliably': 1
# 'argot': 1
# 'hot-slough': 1
# 'prowlers': 1
# 'taunting': 1
# 'etymological': 1
# 'rifling': 1
# 'whimper': 1
# 'objets': 1
# 'd'art': 1
# 'rectitude': 1
# 'malign': 1
# 'recapitulate': 1
# 'Hostaria': 1
# 'Orso': 1
# 'jimmied': 1
# 'Hastening': 1
# 'khaki': 1
# 'eludes': 1
# 'Victrola': 1
# 'tangos': 1
# 'paso': 1
# 'doble': 1
# 'glommed': 1
# 'curio': 2
# 'snuffboxes': 1
# 'jade-handled': 1
# 'sandalwood': 1
# 'Kodaks': 1
# 'afghan': 1
# 'lammed': 1
# 'constables': 1
# 'Javert': 1
# 'gird': 1
# 'effloresce': 1
# 'frambesia': 1
# 'clonic': 1
# 'curtain-raiser': 1
# 'Occidental': 1
# 'delimit': 1
# 'affronted': 1
# 'heisted': 1
# 'obsidian': 1
# 'statuette': 1
# 'earth-touching': 1
# 'Dying': 1
# 'teakwood': 1
# 'Jehovah': 1
# 'Allah': 1
# ''fess': 1
# 'maltreat': 1
# 'Presence': 1
# 'jokers': 1
# 'Khmer': 1
# 'Musee': 1
# 'Guimet': 1
# 'Salpetriere': 1
# 'leprosy': 1
# 'Hell's': 1
# 'chaulmoogra': 1
# 'fantods': 1
# 'imploring': 1
# 'desecration': 1
# 'Sudanese': 1
# 'juju': 1
# 'livers': 1
# 'Khartoum': 1
# 'provenance': 1
# 'applejack': 1
# 'Ganessa': 1
# 'Siva': 1
# 'Krishna': 1
# 'Travancore': 1
# 'subcontinent': 1
# 'Kali': 1
# 'worshiped': 1
# 'Thuggee': 1
# 'Nuf': 1
# 'amulet': 1
# 'housebreakers': 1
# 'mem': 1
# 'rajah': 1
# 'Inscribed': 1
# 'Balinese': 1
# 'Tjokorda': 1
# 'Agoeng': 1
# 'Whosoever': 1
# 'rooftree': 1
# 'cocu': 1
# 'fishmongers': 1
# 'vandals': 1
# 'forty-fifth': 1
# 'pap': 1
# 'gorging': 1
# 'pinball': 1
# 'Ubermenschen': 1
# 'befell': 1
# 'wisenheimer': 1
# 'joss': 1
# 'Bombay': 1
# 'garlanded': 1
# 'cartons': 1
# 'yapping': 1
# 'scarify': 1
# 'areaways': 1
# 'exasperate': 1
# 'Evenings': 1
# 'Paglieri's': 1
# 'Backyard': 1
# 'donning': 1
# 'Sole': 1
# 'Mio': 1
# 'arboreal': 1
# 'chivying': 1
# 'retaliate': 1
# 'stubbed': 1
# 'contentedly': 1
# 'tallow': 1
# 'crisscrossed': 1
# 'Spector': 1
# 'process-server': 1
# 'Grimesby': 1
# 'Roylott's': 1
# 'speckled': 1
# 'incubi': 1
# 'masterly': 1
# 'beggary': 1
# 'hubris': 1
# 'plumbed': 1
# 'bathos': 1
# 'besmirched': 1
# 'extremis': 1
# 'pityingly': 1
# 'horoscope': 1
# 'sidle': 1
# 'Bodhisattva': 1
# 'hors': 1
# 'yaws': 1
# 'fluke': 1
# 'bilharziasis': 1
# 'Compassionately': 1
# 'Perelman': 1
# 'exhaling': 1
# 'aviary': 1
# 'olive-flushed': 1
# 'coral-colored': 1
# 'boucle': 1
# 'stupefying': 1

# %%
def create_vocab(word_freq, V=20000):
    # Sort the word frequencies dictionary by frequency in descending order
    sorted_words = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
    
    # Take the top V most frequent words
    most_common_words = sorted_words[:V]
    
    # Create a vocabulary dictionary mapping words to unique indices
    vocab = {word: i for i, (word, _) in enumerate(most_common_words)}
    return vocab

# Example usage
vocab = create_vocab(word_frequencies)

# %%
print(vocab)
# Out:
# {'the': 0, ',': 1, '.': 2, 'of': 3, 'and': 4, 'to': 5, 'a': 6, 'in': 7, 'that': 8, 'is': 9, 'was': 10, 'for': 11, '``': 12, "''": 13, 'The': 14, 'with': 15, 'it': 16, 'as': 17, 'he': 18, 'his': 19, 'on': 20, 'be': 21, ';': 22, 'I': 23, 'by': 24, 'had': 25, 'at': 26, '?': 27, 'not': 28, 'are': 29, 'from': 30, 'or': 31, 'this': 32, 'have': 33, 'an': 34, 'which': 35, '--': 36, 'were': 37, 'but': 38, 'He': 39, 'her': 40, 'one': 41, 'they': 42, 'you': 43, 'all': 44, 'would': 45, 'him': 46, 'their': 47, 'been': 48, ')': 49, '(': 50, 'has': 51, 'will': 52, 'who': 53, 'more': 54, 'out': 55, 'It': 56, 'we': 57, 'she': 58, 'said': 59, 'there': 60, 'up': 61, 'In': 62, ':': 63, 'than': 64, 'them': 65, 'into': 66, 'no': 67, 'its': 68, 'about': 69, 'so': 70, 'when': 71, 'can': 72, 'only': 73, 'other': 74, '!': 75, 'could': 76, 'time': 77, 'if': 78, 'what': 79, 'some': 80, 'But': 81, 'A': 82, 'two': 83, 'any': 84, 'may': 85, 'do': 86, 'first': 87, 'like': 88, 'these': 89, 'over': 90, 'such': 91, 'This': 92, 'me': 93, 'my': 94, 'man': 95, 'our': 96, 'made': 97, 'new': 98, 'most': 99, 'now': 100, 'then': 101, 'must': 102, 'also': 103, 'Af': 104, 'did': 105, 'even': 106, 'back': 107, 'before': 108, 'years': 109, 'through': 110, 'And': 111, 'many': 112, 'She': 113, 'much': 114, 'way': 115, 'down': 116, 'your': 117, 'should': 118, 'There': 119, 'where': 120, 'They': 121, 'Mr.': 122, 'after': 123, 'because': 124, 'people': 125, 'too': 126, 'little': 127, 'those': 128, 'very': 129, 'own': 130, 'make': 131, 'good': 132, 'each': 133, 'well': 134, 'work': 135, 'just': 136, 'men': 137, 'If': 138, 'still': 139, 'see': 140, 'get': 141, 'between': 142, 'long': 143, 'being': 144, 'world': 145, 'We': 146, 'know': 147, 'same': 148, 'life': 149, 'might': 150, 'us': 151, 'never': 152, 'year': 153, 'under': 154, 'For': 155, 'both': 156, 'last': 157, 'off': 158, 'day': 159, 'how': 160, 'came': 161, 'against': 162, 'used': 163, 'great': 164, 'here': 165, 'go': 166, 'himself': 167, 'right': 168, 'come': 169, 'When': 170, 'few': 171, 'take': 172, 'New': 173, 'another': 174, 'American': 175, 'old': 176, 'use': 177, 'while': 178, 'around': 179, 'three': 180, 'As': 181, 'state': 182, 'without': 183, 'found': 184, 'Mrs.': 185, 'again': 186, 'His': 187, 'place': 188, '1': 189, 'home': 190, 'You': 191, 'small': 192, 'thought': 193, 'went': 194, 'say': 195, 'upon': 196, 'What': 197, 'got': 198, 'left': 199, 'number': 200, 'part': 201, 'course': 202, 'United': 203, 'high': 204, 'since': 205, 'during': 206, 'away': 207, 'always': 208, 'fact': 209, '2': 210, 'does': 211, 'States': 212, 'every': 213, 'until': 214, 'water': 215, 'think': 216, 'less': 217, 'enough': 218, 'To': 219, 'took': 220, 'put': 221, 'head': 222, 'something': 223, 'One': 224, 'hand': 225, 'school': 226, 'once': 227, 'told': 228, 'far': 229, 'At': 230, 'set': 231, 'almost': 232, 'better': 233, 'public': 234, 'end': 235, 'house': 236, 'night': 237, 'called': 238, 'find': 239, 'knew': 240, 'system': 241, "didn't": 242, 'going': 243, 'eyes': 244, "don't": 245, 'asked': 246, 'however': 247, 'group': 248, 'toward': 249, 'give': 250, 'days': 251, 'point': 252, 'though': 253, 'possible': 254, 'program': 255, 'given': 256, 'present': 257, 'face': 258, 'per': 259, 'side': 260, 'room': 261, 'looked': 262, 'important': 263, 'look': 264, 'order': 265, 'business': 266, 'next': 267, 'things': 268, 'John': 269, 'become': 270, 'young': 271, 'nothing': 272, 'No': 273, 'later': 274, 'felt': 275, 'That': 276, 'social': 277, 'case': 278, 'Then': 279, 'large': 280, 'rather': 281, 'need': 282, 'form': 283, 'saw': 284, 'often': 285, 'On': 286, 'These': 287, 'least': 288, 'children': 289, 'along': 290, 'best': 291, 'second': 292, 'several': 293, 'ever': 294, 'seemed': 295, 'early': 296, 'Of': 297, 'thing': 298, 'four': 299, 'power': 300, 'want': 301, 'mind': 302, 'interest': 303, 'within': 304, 'turned': 305, 'light': 306, 'area': 307, "'": 308, 'done': 309, 'big': 310, 'among': 311, 'problem': 312, 'members': 313, 'country': 314 ...

# %%
def windowizer(text):
    words = text.split()
    windows = [f"{words[i]} {words[i + 1]}" for i in range(len(words) - 1)]
    return windows

windows = windowizer(corpus)

# %%
print(windows[:5])
# Out:
# ['The Fulton', 'Fulton County', 'County Grand', 'Grand Jury', 'Jury said']

# %%
import numpy as np

def build_co_occurrence_matrix(vocab, windows):
    vocab_size = len(vocab)
    matrix = np.zeros((vocab_size, vocab_size), dtype=np.int32)
    for window in windows:
        word1, word2 = window.split()
        if word1 in vocab and word2 in vocab:
            idx1, idx2 = vocab[word1], vocab[word2]
            matrix[idx1, idx2] += 1
            matrix[idx2, idx1] += 1  # Symmetric matrix
    return matrix

co_occurrence_matrix = build_co_occurrence_matrix(vocab, windows)

# %%
print(co_occurrence_matrix)
# Out:
# [[   0 3758    2 ...    4    0    1]
#  [3758  146    1 ...    0    0    0]
#  [   2    1    0 ...    1    2    0]
#  ...
#  [   4    0    1 ...    0    0    0]
#  [   0    0    2 ...    0    0    0]
#  [   1    0    0 ...    0    0    0]]

# %%
from scipy.spatial.distance import cosine

def cosine_similarity(vec1, vec2):
    # Calculate cosine similarity manually
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

def get_most_similar_words(matrix, vocab, test_word, top_n=5):
    if test_word not in vocab:
        return []
    
    word_idx = vocab[test_word]
    word_vector = matrix[word_idx]
    
    # Calculate similarities directly with cosine similarity
    similarities = [
        (word, cosine_similarity(word_vector, matrix[idx]))
        for word, idx in vocab.items() if word != test_word
    ]
    
    # Sort by similarity in descending order and get the top_n
    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

# Example usage
test_word = 'government'
similar_words = get_most_similar_words(co_occurrence_matrix, vocab, test_word)
print(similar_words)

test_word2 = 'investigation'
similar_words2 = get_most_similar_words(co_occurrence_matrix, vocab, test_word2)
print(similar_words2)

test_word3 = 'county'
similar_words3 = get_most_similar_words(co_occurrence_matrix, vocab, test_word3)
print(similar_words3)

test_word4 = 'jury'
similar_words4 = get_most_similar_words(co_occurrence_matrix, vocab, test_word4)
print(similar_words4)
# Out:
# [('water', 0.9192449021679032), ('light', 0.9170041849389351), ('land', 0.9129898977324399), ('direction', 0.9106910402994063), ('law', 0.910225066628261)]
# [('interpretation', 0.8759447578528412), ('destruction', 0.8728507057970645), ('application', 0.8719779764954689), ('expression', 0.8693387231611925), ('absurdity', 0.8636869876790825)]
# [('French', 0.8375300809329476), ('city', 0.8356498827161863), ('X-region', 0.8350790119161771), ('Bosphorus', 0.8293899053581143), ('woods', 0.8273224348236593)]
# [('congregation', 0.8843715766701069), ('historian', 0.8801438321272178), ('police', 0.8777896985059777), ('road', 0.8756309518966021), ('former', 0.8731587864462476)]

# %% [markdown]
# # Part 2: Applications of Dense Representations of Words

# %% [markdown]
# ## Task A - Fine-grained Supermarket Product Segmentation

# %%
#Data Loading
import pandas as pd

products_df = pd.read_csv('products.csv')
aisles_df = pd.read_csv('aisles.csv')

# %%
#Preprocessing
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def cleanup_text(text):
    # Clean text here if necessary
    return text.lower()

def process_product_name(name):
    words = cleanup_text(name).split()
    return [word for word in words if word not in stop_words]

products_df['processed_name'] = products_df['product_name'].apply(process_product_name)
# Out:
# [nltk_data] Downloading package stopwords to /Users/User2/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Embedding and Clustering
import torchtext
from torchtext.vocab import FastText

fasttext = FastText(language='en')

def get_mean_embedding(words):
    embeddings = [fasttext[word] for word in words if word in fasttext.stoi]
    return sum(embeddings) / len(embeddings) if embeddings else None

products_df['embedding'] = products_df['processed_name'].apply(get_mean_embedding)
embeddings = products_df['embedding'].dropna().tolist()

# %%
#K-Means Clustering
import numpy as np
from sklearn.cluster import KMeans

# Ensure all embeddings are numpy arrays and have the same shape
products_df['embedding'] = products_df['embedding'].apply(lambda x: np.array(x) if x is not None else None)

# Drop any products with missing or inconsistent embeddings
products_df = products_df.dropna(subset=['embedding'])

# Check that all embeddings have the same shape
embedding_length = len(products_df['embedding'].iloc[0])
products_df = products_df[products_df['embedding'].apply(lambda x: len(x) == embedding_length)]

# Convert the list of embeddings to a 2D numpy array
embeddings_array = np.vstack(products_df['embedding'].values)

# Run K-means clustering
n_clusters = 5  # Adjust based on experimentation
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
products_df['cluster'] = kmeans.fit_predict(embeddings_array)

# Display cluster members
for cluster in range(n_clusters):
    cluster_members = products_df[products_df['cluster'] == cluster]['product_name']
    print(f"Cluster {cluster}: {cluster_members.tolist()}")
# Out:
# /Users/User2/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Cluster 0: ['Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce', 'Green Chile Anytime Sauce', "Cut Russet Potatoes Steam N' Mash", 'Rendered Duck Fat', 'Pizza for One Suprema  Frozen Pizza', 'Pomegranate Cranberry & Aloe Vera Enrich Drink', 'Salted Caramel Lean Protein & Fiber Bar', 'Fancy Feast Trout Feast Flaked Wet Cat Food', 'Fresh Cut Golden Sweet No Salt Added Whole Kernel Corn', 'White Pearl Onions', 'European Cucumber', 'School Glue, Washable, No Run', 'Pumpkin Muffin Mix', 'Mirabelle Brut Rose', 'Medium Taqueria Style Chipotle Salsa', "Autumn Vegetable & Turkey Dinner with Lil' Bits Purees Dinner", 'European Style Spring Mix', "Artisan Chick'n & Apple Sausage", 'Wild Albacore Tuna No Salt Added', 'French  Tarragon Wine Vinegar', 'Lamb Shank', 'Classics Earl Grey Tea', 'Meat In The Middle Large Rawhide Chews', 'Organic Blueberry Blitz Fruit & Veggie Smoothie Mashups', '2% Yellow American Cheese', 'Bread, Healthy Whole Grain', 'Sprouted Kale Cracker', 'Organic Yummy Tummy Maple & Brown Sugar Instant Oatmeal', 'Mild Salsa Divino', 'Uncured Turkey Bologna', 'English Muffins', 'Petit Suisse Fruit', 'Ground Turkey Chub', 'Chardonnay Paso Robles', 'Sharp Cheddar', 'Sherry Reserve Vinegar', 'Olli Napoli Salami', 'Zita Cut, No. 118', 'Restaurant Style Organic Chia & Quinoa Tortilla Chips', 'Coarse Grind Garlic Powder & Parsley Blend', 'Traditional Water Crackers', 'Wild Blueberry All Natural Fruit Spread', '3 in 1 Soap for Every Man, Cucumber & Lemon', 'Smoked Ham & Oven Roasted Turkey Sub Sandwich Kit', 'Calcium Adult Gummy Vitamins, Orange Cherry & Strawberry', 'Halves & Pieces Walnuts', 'Original Turkey', 'Citrus Terere Yerba Mate', 'Simply Beyond Black Bean Tortilla Chips', 'Cookie Dough Performance Energy', 'Mild El Nino Salsa', 'Healthfull Nuts & Seeds Bread', 'Israeli Style Gefilte Fish', 'Herb Thyme Clamshell', 'Sloppy Joe', 'Homemade Hot Arrabbiata Fra Diavolo Sauce', 'Gluten Free Oatmeal, Variety Pack', 'Cayenne Lemonade Made With Raw Tristate Honey', 'Blue Bottle Coffee Frozen Bar', 'Chinese Breakfast Black Tea', 'Tennessee Whiskey', "Nature's Seasons Seasoning Blend", 'Original Red Twists', 'Pinot Grigio, California, 2010', 'Waffles, Red Berry', 'Cold Remedy, Quick Dissolve Tablets, Cherry Flavor', 'Imported Italian Solid Light Tuna In Pure Olive Oil', 'Petite Dill Pickles', 'Red Food Color', 'Non-Fat Blueberry on the Bottom Greek Yogurt', 'Rio Berry', 'Triple Chocolate Ripple', 'TAI PEI      14OZ.SWEET & SOUR CHKN', 'Thin Stackers Brown Rice  Salt Free', 'Everyday Detox Dandelion Tea', 'Chai Tea Bags', 'Oh My Cod! Cod Pate and Vegetables Cat Food', 'Mini Nilla Wafers Munch Pack', 'Lite Poppy Seed Dressing Lite', 'Turkey', 'Prime Filets Chicken & Tuna Dinner in Gravy Cat Food', 'Minis Original Saltine Crackers', 'Chewables Extra Strength Cherry Creme - 48 CT', 'Gourmet Dog Treats Bone', 'Candy, Original', "Graduates Lil' Entrees Spiral Pasta In Turkey Meat Sauce With Green & Yellow Beans", 'Crackers, Puffed, Corn, Quinoa & Sesame', 'Peppermint/Banana Split Variety Pack Frozen Dairy Dessert Cones', 'Best Grains Honey & Crunch Oat Bread', 'Strong & Kind Roasted Jalapeno Almond Protein Bar', 'Veggie-Style Mini Corn Dogs', 'Green Peas, Organic, Petite', 'Basil Daly Bar Soap', 'Soap, Pure-Castile, 18-in-1 Hemp, Lavender', 'Complete Health Deboned Chicken, Chicken Meal and Rice Cat Food', 'Extra Strength Berry', "Mixed 12 Pack Lion's Share Ale", 'Colby Jack & Mild Cheddar Combo Pack', 'Water Crackers Original All Natural', 'Greener Selection Salad', 'New Mexico Chili', 'Moisture Rich Sweet Orange & Argan Conditioner', 'Even & Bright Pink Lemon and Mandarin Orange Body Wash', 'Super Dry Beer', 'Real Chicken & Veggies Recipe Dog Food', 'Stove Top Stuffing Mix for Turkey', 'Mache Blend', 'Organic Yukon Gold Potato Bag', 'OPA Greek Yogurt Ranch Dressing', 'Flat Floss, Antiplaque, Naturally Waxed, Spearmint', 'Ultra Thin Pastrami', 'Almond Glow Almond Body Lotion/Massage Oil', 'Original Bite Size Candies Natur ...
# Cluster 1: ['All-Seasons Salt', 'Pure Coconut Water With Orange', 'Gluten Free Quinoa Three Cheese & Mushroom Blend', 'Organic Turkey Burgers', 'Organic Sourdough Einkorn Crackers Rosemary', 'Organic Clementines', 'Banana & Sweet Potato Organic Teething Wafers', 'Organic Red Wine & Olive Oil Dressing Organic', 'Organic Honeycrisp Apples', 'Hemp Protein, Organic', 'Organic Rice Vinegar', 'Sprinklez Confetti Fun Organic Toppings', 'Organic Chamomile Lemon Tea', 'Organic Sprouted Barley Bread', "Infant's Blend Probiotic", 'Organic Wild Blueberries', 'Organic Lemons', 'Organic Ranch Veggie Dip', 'Living Organic Cilantro', 'Hacho Miso Aged & Fermented Soybeans', 'Organic Mini Homestyle Waffles', 'Peanut Butter Cacao Quinoa Clusters', 'Single Herbs Ginkgo Leaf Dietary Supplement', 'Classic Culinary Low Sodium Vegetable Broth', 'Grade A Pasteurized 2% Milkfat Lowfat Cottage Cheese with Pineapple', 'Gluten Free Organic Cereal Coconut Maple Vanilla', 'Organic Blue Corn Sea Salt Tortilla Chips', '6\\" Organic Carrot Cake', '3 Seed Blue Corn Dipping Chips', 'Organic Soups Lentil', 'Alpha-Bits Multigrain Cereal', 'Taco Reduced Sodium Seasoning Mix', 'Poppy Seed Bagels', 'Organic Vegetable Greens & Greens Juice Blend', 'Cantaloupe', 'Organic Southwestern Burrito', 'Diet Root Beer', 'Organic Whole Wheat Elbows', 'Original Sprouted Grains Protein & Fiber Hot Oatmeal', 'Organic Apple Spinach Kale Coconut Water Superjuice', 'Organic Enriched Unbleached White Flour', 'Wild Forest Raw Neem Honey', 'Gold Potatoes', 'Glycerine Soap, Pure and Natural, Cucumber', 'Organic Whole Grassmilk Milk', 'Organic Lemon Gingersnap', 'Organic Whole Peeled Baby Carrots', 'Organic Granulated Tapioca', 'Ground Flaxseed With Mixed Berries', 'Cashews Natural Unsalted', 'Pure Granulated Cane Sugar', 'Organic Hard Candy Blood Orange and Honey', 'Organic Strawberry Lemon-ade', 'Reg; Organic Apple Cider Vinegar 16 Fl Oz', '100% Organic Diced Tomatoes', 'Organic Whole Granulation Roasted Buckwheat Groats', 'Fiber 4g Gummy Dietary Supplement', 'Salt Free Seasoning', 'Organic Reposado Tequila', 'Organic Pitted Kalamata Olives', 'Most Wanted Cabernet Sauvignon Red Wine', 'Organic Orange Turmeric Juice', 'Pure Cane Granulated W/Spout Sugar', 'Arrowroot Powder', 'Starting Solids Carrots Organic Baby Food', 'Protein Blend Honey Oats & Seeds Cereal', 'Lecithin Granules Non-GMO', 'Organic Lowfat Pomegranate Acai Kefir Probiotic Cultured Milk Smoothie', 'Antioxidant Infusions Brasilia Blueberry', 'Granola, Veritas, Organic', 'Red Seedless Grapes Imported', 'Organic Raw Almond Butter', 'Pure Moringa Vegetable Powder', 'Organic Thin Sliced 100% Whole Wheat Bread', 'Organic Blueberry Pomegranate Whole Milk Yogurt', 'Dailyfoods Vitamin D-3 2000 IU', 'Cabernet Sauvignon California', 'Plain Dairy-Free Probiotic Drinkable Cashewgurt', 'Organic Mozzarella', 'Organic Hearty Garden Vegetable Soup', 'Organic California Blend', 'Organic Southwestern Vegetable Soup', 'Organic Fruit Punch', 'Organic Salted Butter', 'Nutrition Bar, Raw Organic, Pineapple Almond + Raw Protein', 'Organic Elmo Vegetable Soup', 'Organic Porcini Mushroom Risotto', 'Organic Promise Strawberry Fields Cereal', 'Wraps, Turmeric', 'Superfood Bar Goji Acai Organic', 'Organic Raw Coconut Aminos', 'Xylitol Sweetener', 'Organic Fiber Fruit Blend', 'Organic 100% Whole Wheat Rigatoni', 'Organic Dried Cranberries', 'Organic Shredded Mild Cheddar', 'Organic Vegetable Tray', 'Organic Pasteurized Apple Juice', 'Organic Spinach Quinoa Powermeal Bowl', 'Organic Fuel, High Protein Milk Shake, Vanilla', 'Organic Classic Caraway Kraut', 'Organic Super Berry Juice', 'Heirloom Boysenberries', 'Vitamin D3 1000 I.U Vegetable Capsules', 'Organic Honey Mustard', 'Healthy Grains Oats & Honey Clusters with Toasted Coconut Gluten Free', 'Pomegranate Coconut Sparkling Probiotic Drink, Organic', 'Unsweetened Original Organic Soy Non-Dairy Beverage', 'Organic Mango Mania ZFruit and Veggie Rope', 'Organic Smooth Move Chamomile Laxative Tea Bags', ' ...
# Cluster 2: ['Dry Nose Oil', 'Saline Nasal Mist', 'Fresh Scent Dishwasher Cleaner', 'Overnight Diapers Size 6', 'Small & Medium Dental Dog Treats', 'Fresh Breath Oral Rinse Mild Mint', 'Tri-Vi-Sol® Vitamins A-C-and D Supplement Drops for Infants', 'Complete Spring Water Foaming Antibacterial Hand Wash', 'Ultra Antibacterial Dish Liquid', 'Biotin 1000 mcg', 'Sa Extra Hold Mousse Hair Styling', '24/7 Performance Cat Litter', 'Lasting Color Shampoo', 'Flat Toothpicks', 'Ultra 7 Inch Polypropylene Traditional Plates', 'Camilia, Single Liquid Doses', 'Probiotics High Potency Capsules', 'Kind Prenatal Once Daily', 'Easy Grab 9\\"x13\\" Oblong Glass Bakeware', 'Fabric Softener, Geranium Scent', 'Herbal Armor DEET-Free Natural Insect Repellant', 'Purifying Daily Detox Scrub', 'Stain Release Boost In-Wash Stain Remover Pacs', 'Simple', 'Anti Diarrheal Caplets', 'Aromatherapaes Stress Reducing Lavender & Chamomile Spa Bath', 'Fabric Refresher Meadows & Rain Air Freshener (1 Count, 27 oz)  Air Care', '100% Recycled Aluminum Foil', 'Vanishing Acne Treatment Cream', 'Acti-Fresh Body Shape Long Unscented To Go Panty Liners', 'Fresh Scent Dishwasher Detergent with Dawn', 'Radiant Pantiliners Regular Wrapped Unscented', 'Rescue Remedy, Spray', 'Free & Clear Natural Laundry Detergent For Sensitive Skin', 'Argan Oil of Morocco Renewing Weightless Healing Dry Oil Hair Oil', 'Totz Toothbrush Extra Soft 18+ Months', 'Tegaderm Waterproof Transparent Dressing', 'Foaming Hand Soap Kid Watermelon', 'EcoNet Recycled Bath Sponge', 'Low Sodium Turkey', 'Triple-Acting Laundry Stain Remover', 'Extra Strength Melatonin Adult Gummies', 'Glass Storage Container with Green Silicone Protection', 'Sponge Mop', 'OneZip Storage Bags Quart Size Value Pack', 'Propolis Herbal Supplement', 'Makeup Remover Cleansing Towelettes', 'Mint Dental Floss', 'Fresh Multi-Purpose Contact Lens Solution', 'For Men Odor Armor Body Wash', 'Write Bros Ball Point Pens, Cap-Pen, Medium (1.0 mm), Black Ink', 'Biotin 10,000mcg Maximum Strength', 'Advanced Haircare Color Vibrancy Nourishing Shampoo', 'Extra Whitening Multi-Benefit Fluoride Toothpaste', 'Revive Anti-Perspirant Deodorant', 'Echinacea Goldenseal Alcohol Free Extract', 'Natural Food Color Packets', 'Disinfectant Spray Cherry Blossom & Pomegranate Scent', 'Yahrzeit Light Memorial Candle', 'Super Slimming Herbal Tea', 'Go Fresh Nutrium Moisture Body Wash Blue Fig & Orange Blossom Scent', 'Twist n Loc Small Round Containers + Lids', 'White Writing Gel', 'Day and Night Multi-Symptom and Severe Cold & Cough Pain Reliever/Fever Reducer', 'Vitamin C 1000 Mg Tropical Drink Mix Dietary Supplement', 'Ultimate Omega 1000 mg Lemon Soft Gels', 'Fabric Softener Dryer Sheet Free & Gentle 200CT Fabric Enhancers', 'Powerball Quantum Max Shine & Protect Automatic Dishwasher Detergent', 'Clementine Bag', 'EverCurl Hydracharge Conditioner', 'Super Enzymes', 'Phoenix Anti-Perspirant & Deodorant Stick Twin Pack', 'Aquaphor Healing Ointment', 'Pink Vitamin C 1000 Mg Pink Lemonade Drink Mix', 'Super Plus Cardboard Applicator Unscented Tampons', 'Brazilian Keratin & Argan Oil Leave-In Conditioning & Styling Elixir', 'Dual Action Beta Immune and Anti-Oxidant Effervescent Citrus', 'Laundry Soil Stain Remover', 'Everyday Mega Pack Paper Plates', 'Beach Sage Liquid Fabric Softener', 'Antioxidant Cranberry Body Wash', 'Ultra Power Plus Laundry Detergent 54 loads', 'Tea, Superflower, Hibiscus, Blueberry, Caffeine-Free, Bags', 'Sleepytime Sinus Soother Herbal Tea', 'Ibuprofen Liquid Gels', 'Total Advanced Floss Tip Medium Toothbrush', 'Sore Throat Wild Cherry Lozenges', 'Plastic Measuring Cups', 'Lavender Body Wash', 'Gentle Clean Foaming Face Cleanser, 6.7 fl oz Female Skin Care', 'Can/Bottle Opener, Chrome', 'Pompelmo Water', 'Designer 9 Oz. Paper Cups', 'Daily Moisture Shampoo', 'Aspirin 325 Mg', 'Non-Scratch Scrub Sponges', 'Proactive Health Mature Adult Hairball Care Cat Food', 'Freezer Safe Pint Jars Wide Mouth', 'Daily Shower Cleaner Ylang Ylang', 'Bi ...
# Cluster 3: ['Chocolate Sandwich Cookies', 'Robust Golden Unsweetened Oolong Tea', 'Light Strawberry Blueberry Yogurt', 'Sparkling Orange Juice & Prickly Pear Beverage', 'Peach Mango Juice', 'Chocolate Fudge Layer Cake', 'Mint Chocolate Flavored Syrup', 'Wheat Chex Cereal', 'Peanut Butter Cereal', 'Daily Tangerine Citrus Flavored Beverage', 'Sparkling Raspberry Seltzer', 'Raisin Cinnamon Bagels 5 count', 'Whole Leaf Pure Aloe With Lemon Juice', 'Healthy Pop Butter Popcorn', 'Jelly, Blackberry', 'Vanilla with Almond Milk Iced Coffee', 'Jasmine Tea Unfiltered Ginger Ale', 'Coconut Chocolate Chip Energy Bar', 'Nutter Butter Cookie Bites Go-Pak', 'All Natural 100% Apple Juice', 'Smorz Cereal', 'Peanut Butter & Strawberry Jam Sandwich', 'Danish Butter Cookies', 'Grape Leaf Hummus Wrap', 'Scooby-Doo! Fruit Flavored Snacks', 'Pomegranate Molasses', 'Sun Cups Dark Chocolate', 'Vanilla Milk Chocolate Almond Ice Cream Bars Multi-Pack', 'Yogurt Strawberry Pomegranate', 'Dark Chocolate Ice Cream Topping', 'Very Vanilla Soymilk', 'Nectarines', 'Brut Rosé', 'Corn Dogs, Mini, Honey Crunchy Flavor', 'Extra Spearmint Sugar-Free Gum', 'Sparkling Blush Grape Juice', 'Gluten Free All Natural Chocolate Chip Cookies', 'Kisses Milk Chocolate Candy', 'fruitwater® Strawberry Kiwi Sparkling Water', 'Soda', 'Cold Brew Coffee Tahitian Vanilla', 'Chocolate Mint Cookie Crunch Nutrition Bar', 'Minis Candy Bars', 'Vanilla Almond Cashew Almondmilk Cashewmilk Blend', 'Honey Nut Oatmeal Squares', 'Kiwi Strawberry Sparkling Water', 'Triple Chocolate Snack Size', 'Vanilla Cream Soda', 'Gluten Free Blueberry Muffin Mix', 'Brambleberry Herbal Tea', 'Dried Sweetened Cranberries', 'Island Fruits Fruit Snacks', 'Key Lime Soda', 'French Vanilla Ice Cream', '100% Juice No Sugar Added Fruit Punch', 'Organic Peppermint Lemonade', 'Brisk With Lemon Iced Tea', 'Apple Cinnamon Crisp Candle', 'Raspberry Fig Bars', 'Sparkling Raspberry Lemonade Water Beverage', 'Blueberry Kombucha', 'Black Currant Kombucha', 'Creamline Yogurt Wild Blueberry', 'Eco-Pac Kamut Puffs Cereal', 'Lime Sherbet', 'Pound Cake Cake Mix', 'Cheerios Cereal', 'Chocolate Caramel Whey Protein Bar', 'Juniper Berry Soda', 'Toaster Pops Strawberry', 'Sugar Free Mint Patties', 'Liquid Drink Mix Blackberry Lemonade', 'Chocolate Brownie Flavor Protein Bar', 'Sweet Cream Buttermilk Powder', 'Grass-Fed Yogurt Blueberry Cardamom', 'Vanilla Almond Protein Bar', 'Holiday Sugar Plum Spice Herbal Tea', 'Ice Cream, Cookies & Cream', 'Vanilla Almond Breeze Almond Milk', 'Dark Chocolate Raisins', 'Strawberry Cheesecake Nonfat Yogurt', 'Crispy Cinnamon Pear Chips', 'Almond Honey Protein+ Bar', 'Blueberry Pomegranate Acaí Cultured Goat Milk Kefir', 'Chips Ahoy! Chewy Cookies', 'Almond Spread, Dark Chocolate', 'Sparkling Blueberry', 'Honey Vanilla Greek Yogurt', 'Acai Dragonfruit Melon Green Tea', 'Whipping Cream', 'Lite Beer', 'Slow Churned Mint Chocolate Chip Ice Cream', '\\"Constant Comment\\" Decaffeinated Black Tea Blend', 'Lowfat Raspberry Kefir Probiotic Cultured Milk Smoothie', 'Gin Gins Candy', 'Pear and Blueberry Baby Breakfast', 'Yellow Cherry Tomato', 'Mascarpone Pistachio Caramel Gelato', 'Frozen Desserts, Fit, Salted Caramel', 'Multigrain Pop Cakes', 'Coffee Liqueur', 'Alcohol Free Maple Flavor', 'Hi-Chew Strawberry Fruit', 'Cranberry Almond Fruit Clusters Dried Cranberries', 'Organic Mango Peach Carrot Kickstart Smoothie', 'Cookie Chips Crunchy Dark Chocolate Chocolate Chip Cookies', 'Crunch Vanilla Sugar Mini Cookies', 'Vanilla Sugar Cookies', 'Garnet Sweet Potato (Yam)', 'Vanilla Incense of Auroville', 'Oreo Cookies and Cream Chocolate Frozen Dairy Dessert', 'Gluten Free Peanut Butter Berry  Chewy With A Crunch Granola Bars', 'Banana Chocolate Chip', 'Salted Caramel Ice Cream', 'Goober Strawberry', 'Sparkling Lemon Seltzer Water', 'Clarified Lime Juice', 'Apple Sparkling Juice Beverage', 'Fudge Brownies with English Walnuts', 'Snack Size Candy', 'Red Raspberry Jam', 'Multigrain Peanut Butter Cereal', 'Melanie Me ...
# Cluster 4: ['Three Cheese Ziti, Marinara with Meatballs', 'Nacho Cheese White Bean Chips', 'Organic Spaghetti Style Pasta', 'Italian Herb Porcini Mushrooms Chicken Sausage', 'Traditional Lasagna with Meat Sauce Savory Italian Recipes', 'Noodle Soup Mix With Chicken Broth', 'Beef Hot Links Beef Smoked Sausage With Chile Peppers', 'Onion Flavor Organic Roasted Seaweed Snack', 'Vegetarian Grain Meat Sausages Italian - 4 CT', 'Whole Wheat Tortillas', 'Cheesy Creations Roasted Garlic Parmesan Sauce', 'Ramen Noodles Soup Chicken Mushroom Flavor', 'Premium Deli Oven Roasted Turkey Breast', 'Pancake Mix, Buttermilk', 'Sweet Cooking Rice Seasoning', 'Spinach Basil Garlic Linguini', 'Blakes Chicken Parmesan Dinner', '100% Whole Wheat Pita Bread', 'Soppressata Piccante', 'Yogurt Fruit Dip Sliced Apples', 'Uncured Cracked Pepper Beef', 'Local Living Butter Lettuce', 'High Fiber Tomato Basil Soup', 'Hot Tomatillo Salsa', 'Light Savory Beef Barley Vegetable Soup', 'Cauliflower Florettes', 'Hot & Spicy Chicken Flavor Ramen Noodles', 'Traditional Chicken & Orzo with Lemon Soup', 'Brioche Bachelor Loaf', 'Chips Onion Chipotle Garlic', 'Arugula Salad', 'Artisan Ciabatta', 'Dressing Bleu Cheese', 'Wild Chanterelle Mushroom Ravioli', 'Garlic Parmesan Pita Bread Chips', 'Extra Sharp Cheddar Cheese', 'Steakhouse Onion Burger with Garlic Seasoning', 'Habanero Lime Shrimp Flavor Ramen Noodle Soup', 'T Bone Steak', 'Vegan Santa Fe Style Flour Tortilla Rolled Tacos', 'Penne Rigate With Spinach', 'Country Style Baked Beans', 'Chicken Nugget Meal', 'Wild Sardines in Marinara Sauce', 'Medium Spicy Butter Chicken Simmer Sauce', 'Lamb Rib Chops', 'Tzatziki Cucumber Sauce', 'Spinach & Feta Pierogi', 'Roasted Vegetable Soufflé', 'Italian Pasta Salad', 'Tapatio Salsa Picante Hot Sauce Tortilla Chips', 'Sambal Oelek Ground Fresh Chili Paste', 'String Cheese, Mozzarella', 'Shaved Parmesan Cheese', 'Chicken Meatballs Dog Treats', 'Chicharrones Picante Flavor Pork Rinds', 'Shrimp with Pasta & Vegetables', 'Organic Roasted Garlic Pasta Sauce', 'Perfectly Thymed Pita Crisps Baked', 'Authentic Deep Dish, Spinach & Garlic Pizza', 'Honey Mustard', 'Vegetable Pot Pie', 'Stuffed Crust Five Cheese Pizza', 'Snack Bags', 'Caramel Sauce', 'Instant Mashed Potatoes', 'Organic Spicy Heirloom Marinara Sauce', 'Dry Roasted Pistachios', 'Precious Mozzarella Cheese', 'Naturals Savory Turkey Breakfast Sausage', 'Juicing Carrots', 'Creamy Italian Dressing Marinade', "Steamfresh Chef's Favorites Lightly Sauced Roasted Red Potatoes & Green Beans", 'Brooklyn Pizza Dough', 'Deluxe Sauce Made with 2% Milk Cheese Macaroni & Cheese Dinner', 'Chilpotles in Adobo Sauce', 'Cheese Creations Four Cheese Cheese Sauce', 'Sunflower Bread', 'Vegetable Salad Kit, Sweet Kale', 'Tzatziki Greek Yogurt Dip', 'Ristorante Pizza Spinaci Thin Crust Pizza', 'Frozen All Butter Pound Cake', 'Deli Thin-Sliced Honey Ham', 'Whole Wheat Spanakopita', 'Honey Glazed Carrots', 'Sliced Kosher Salami', 'Multigrain Spaghetti Style Pasta', 'Chunky Beef with Vegetables & Brown Rice Dog Food', 'Breaded Chicken Breast Tenders', '100% Pure Beef Homestyle Patties', 'Gluten Free Chicken Rustica Pizza', 'Whole Grain Linguine Pasta', 'Garlic & Herb Fresh Goat Cheese', 'Linguine Pasta', '2nd Foods Bananas', 'Sliced Chicken Entree Cat Food', 'White Chicken Chili', 'Chow Mein Thin Noodles', 'Hummus Wrap', 'Sloppy Joe Sauce', 'Old Fashioned Vegetable Beef Soup', 'Kabocha Squash', 'Fancy Diced Hot Chilies', 'Chub Mackerel', 'Dough for Turnover Pastries', 'Couscous, Israeli, Garlic Jalapeno', '100% Natural String Cheese Mozzarella Cheese', 'Tikka Masala Curry Sauce', 'Freeze-Dried Edamame Veggie Snack', 'American Cheese Slices', 'Turkey Meatloaf & Mashed Potatoes', 'in Gravy with Carrots Peas & Corn Mashed Potatoes & Meatloaf Nuggets', 'Stuffed Pasta Shells', 'Tomato Paste with Basil, Oregano & Garlic Flavor', 'Rice & Bean Snack Chips With Adzuki Beans Chipotle Cheese', 'Tomatillo Salsa', 'BBQ Concentrate & Marinade Sauce', 'Turkey Chi ...

# %% [markdown]
# ## Task B - Genre Classification with Movie Titles

# %%
#Genre and Title Embeddings
genres = ['action', 'adventure', 'comedy', 'drama', 'fantasy', 'horror', 'romance', 'thriller']
movies = ['The Hangover', 'Shutter Island', 'Fight Club', 'Jumanji', 'Narcos', 'The Matrix',
          'Rush Hour', 'The Mummy', 'Iron Man', 'Silence of the Lambs', 'Batman Begins', 
          'Spider Man', 'The Hobbit', 'Troy', 'Jurassic Park', 'Scary Movie', 
          'Mission Impossible', 'Ted', 'Eat Pray Love', 'The Notebook', 'Love Actually', 
          'The Terminal', 'Crazy Stupid Love', 'Twilight', 'The Martian', 'Pursuit of Happyness']

genre_embeddings = {genre: fasttext[genre] for genre in genres}
movie_embeddings = {movie: get_mean_embedding(process_product_name(movie)) for movie in movies}

# %%
#Genre Assignment Using Cosine Similarity
def cosine_similarity(vec1, vec2):
    return 1 - cosine(vec1, vec2)

def assign_genre(movie_embedding, genre_embeddings):
    similarities = {genre: cosine_similarity(movie_embedding, genre_vec) for genre, genre_vec in genre_embeddings.items()}
    return max(similarities, key=similarities.get)

movie_genres = {movie: assign_genre(embedding, genre_embeddings) for movie, embedding in movie_embeddings.items()}
print(movie_genres)
# Out:
# {'The Hangover': 'comedy', 'Shutter Island': 'adventure', 'Fight Club': 'adventure', 'Jumanji': 'adventure', 'Narcos': 'thriller', 'The Matrix': 'action', 'Rush Hour': 'drama', 'The Mummy': 'horror', 'Iron Man': 'adventure', 'Silence of the Lambs': 'thriller', 'Batman Begins': 'adventure', 'Spider Man': 'adventure', 'The Hobbit': 'fantasy', 'Troy': 'romance', 'Jurassic Park': 'adventure', 'Scary Movie': 'horror', 'Mission Impossible': 'adventure', 'Ted': 'comedy', 'Eat Pray Love': 'romance', 'The Notebook': 'fantasy', 'Love Actually': 'romance', 'The Terminal': 'fantasy', 'Crazy Stupid Love': 'comedy', 'Twilight': 'fantasy', 'The Martian': 'fantasy', 'Pursuit of Happyness': 'adventure'}
